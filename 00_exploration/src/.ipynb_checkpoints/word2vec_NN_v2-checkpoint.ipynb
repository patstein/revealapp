# %% [markdown]
# # Word2Vec + NN

# %% [markdown]
# __Author__: Patrick Steiner
#
# __Created__: 31.03.2020
#
# __Version__: 2
#
# __Description__: Creates sentence embedding based on tf-idf and word-embedding and feeds this in a NN
#
#
#
#
# |Change ID | Date       |  Author             |Change Description                   |
# |----------|------------|---------------------|--------------------------------------|
# |#SK01     | 03.04.2020 | Severin Kappeler    |Re-define corpus with split by sentence rather than by document |
# |#SK02     | 03.04.2020 | Severin Kappeler    |Embedding matrix weighted by TF-IDF score for each word-embedding vector. Using here the "global" TF-IDF. For a given word the "global" TF-IDF score is the average of all the TF-IDF scores for that word over all documents.  |
# |#SK03     | 03.04.2020 | Severin Kappeler    |Apply tokenize.texts_to_sequence to sentence list rather than document list|
# |#SK04     | 03.04.2020 | Severin Kappeler    |Converting label (target) to be on sentence level rather than document level.      |
# |#SK05     | 03.04.2020 | Severin Kappeler    |Adding split to sentence part for features |

# %%
# see also 06-Natural-Language_processing notebooks. This one focuses only on doc2vec.
import pandas as pd
pd.options.mode.chained_assignment = None 
import numpy as np
import re
import nltk
import os
import smart_open
import collections
import scipy.stats as stats
import tensorflow as tf
import gensim
import tqdm
import warnings

from gensim.models.word2vec import Word2Vec
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.test.utils import common_texts
from gensim.test.utils import get_tmpfile

from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, Dense, Flatten, LSTM
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib inline

from nltk import word_tokenize
from nltk.stem import PorterStemmer

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import MultinomialNB
#from sklearn.model_selection import GridSearchCV, RandomSearch
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm, tree
import xgboost
# Out:
# /home/sevi/anaconda3/envs/propulsion2020/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/sevi/anaconda3/envs/propulsion2020/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/sevi/anaconda3/envs/propulsion2020/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/sevi/anaconda3/envs/propulsion2020/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/sevi/anaconda3/envs/propulsion2020/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/sevi/anaconda3/envs/propulsion2020/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Import

# %%
#os.chdir('/Users/patrickrs/Documents/GitLab/patrick-steiner/Exercises')
target = pd.read_csv('../../10_cleaning/data/raw/testing_complaints/train_target.csv', index_col = 0)
features = pd.read_csv('../../10_cleaning/data/raw/testing_complaints/train_features.csv', index_col = 0)

# %%
features = features[0:1000]
target   = target[0:1000]

# %% [markdown]
# ## Cleaning

# %%
#TO DO: Clean the columns (removing missing values)
nltk.download('stopwords')
STOP_WORDS = nltk.corpus.stopwords.words('english')

def clean_sentence(val):
    "remove chars that are not letters or numbers, downcase, then remove stop words"
    regex = re.compile('([^\s\w]|_)+')
    sentence = regex.sub('', val).lower()
    sentence = re.sub("xxxx", "", sentence)
    sentence = re.sub("xxx", "", sentence)
    sentence = re.sub("xx", "", sentence)
    sentence = re.sub("\s\s+", " ", sentence)
       
    # stemming of words (seems not to affect accuracy, but should make things faster
    porter = PorterStemmer()
    words = word_tokenize(sentence)
    sentence = " ".join([porter.stem(word) for word in words])
      
    sentence = sentence.split(" ")
    for word in list(sentence):
        if word in STOP_WORDS:
            sentence.remove(word)  
    sentence = " ".join(sentence)
    
    return sentence

#SK05
#splitting data into sentences
def tokenize_to_sentences(data):
    output_data = data.copy()
    output_data = output_data.apply(nltk.sent_tokenize)
        
    return output_data
# Out:
# [nltk_data] Downloading package stopwords to /home/sevi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#STOP_WORDS

# %%
#runtime: 3'
#create list of all document strings
documents = features['Consumer complaint narrative']
#create list of document strings split by sentence (a list for each document where each document is represented by a list of sentences (strings))
doc_sent = tokenize_to_sentences(documents)
#create list of document strings split by cleaned sentences
doc_sent_clean = [[clean_sentence(sentence) for sentence in document] for document in doc_sent]

# %%
documents[0:2]
# Out:
# 0    I have an installment loan out with Oklahoma C...
# 1    I was told by the Department of Education to c...
# Name: Consumer complaint narrative, dtype: object

# %%
doc_sent[0:2]
# Out:
# 0    [I have an installment loan out with Oklahoma ...
# 1    [I was told by the Department of Education to ...
# Name: Consumer complaint narrative, dtype: object

# %%
doc_sent_clean[0:2]
# Out:
# [['instal loan oklahoma credit ok call cell phone numer time unknownblock number',
#   'ask stop simpl fact answer call call result know tri get reach regard loan',
#   'know cfpb regul compani hide ident'],
#  ['wa told depart educ contact thi collect compani',
#   'told depart educ collect compani loan belong becaus name chang debt seven year old',
#   'accord rule fcra debt suppos delet system becaus inaccur']]

# %%
#'patiencei'  [sentence for doc in doc_sent_clean for sentence in doc]

# %%
#Build Corpus: #SK01
#runtime: 15''
def build_corpus(data):
    return [nltk.word_tokenize(sentence) for doc in data for sentence in doc]

corpus = build_corpus(doc_sent_clean)

#Old version:
# def build_corpus(data):
#     "Creates a list of lists containing words from each sentence"
#     corpus = []
#     for content in data:
#         corpus_temp = nltk.word_tokenize(content)
#         corpus.append(corpus_temp)
#     return corpus

# corpus = build_corpus(features)

# %%
#Number of sentences overall (can contain duplicates!):
len(corpus)
# Out:
# 10960

# %%
#corpus
# Out:
# [['instal',
#   'loan',
#   'oklahoma',
#   'credit',
#   'ok',
#   'call',
#   'cell',
#   'phone',
#   'numer',
#   'time',
#   'unknownblock',
#   'number'],
#  ['ask',
#   'stop',
#   'simpl',
#   'fact',
#   'answer',
#   'call',
#   'call',
#   'result',
#   'know',
#   'tri',
#   'get',
#   'reach',
#   'regard',
#   'loan'],
#  ['know', 'cfpb', 'regul', 'compani', 'hide', 'ident'],
#  ['wa', 'told', 'depart', 'educ', 'contact', 'thi', 'collect', 'compani'],
#  ['told',
#   'depart',
#   'educ',
#   'collect',
#   'compani',
#   'loan',
#   'belong',
#   'becaus',
#   'name',
#   'chang',
#   'debt',
#   'seven',
#   'year',
#   'old'],
#  ['accord',
#   'rule',
#   'fcra',
#   'debt',
#   'suppos',
#   'delet',
#   'system',
#   'becaus',
#   'inaccur'],
#  ['student',
#   'loan',
#   'payment',
#   'around',
#   '34000',
#   'month',
#   'sever',
#   'year',
#   'without',
#   'notic',
#   '2018',
#   'payment',
#   'went',
#   '72000',
#   'month'],
#  ['call', 'ae', 'ask', 'option', 'see', 'whi', 'increas', 'occur'],
#  ['explain', 'wa', 'pay', 'interest', 'onli'],
#  ['ask', 'option', 'lower', 'payment', 'wa', 'unprepar', 'make', 'payment'],
#  ['said', 'option', 'avail'],
#  ['suggest', 'tri', 'consolid'],
#  ['time',
#   'found',
#   'bank',
#   'consolid',
#   'wa',
#   'far',
#   'behind',
#   'payment',
#   'could',
#   'consolid',
#   'wa',
#   'receiv',
#   'threaten',
#   'letter',
#   'phone',
#   'call',
#   'would',
#   'ruin',
#   'credit',
#   'garnish',
#   'wage'],
#  ['purchas',
#   'vw',
#   'jetta',
#   'gli',
#   'az',
#   'financ',
#   'well',
#   'fargo',
#   'dealer',
#   'servic',
#   'wfd'],
#  ['time',
#   'purchas',
#   'complet',
#   'sale',
#   'maintain',
#   'current',
#   'valid',
#   'auto',
#   'insur',
#   'polici'],
#  ['thi',
#   'auto',
#   'insur',
#   'polici',
#   'wa',
#   'list',
#   'file',
#   'agreement',
#   'purchas',
#   'insur',
#   'time',
#   'sale',
#   'wa',
#   'complet'],
#  ['contact',
#   'auto',
#   'insur',
#   'confirm',
#   'thi',
#   'purchas',
#   'addit',
#   'new',
#   'vehicl'],
#  ['note', 'took', 'possess', 'vehicl', 'monday'],
#  ['month',
#   'later',
#   'wfd',
#   'sent',
#   'written',
#   'request',
#   'notifi',
#   'need',
#   'purchas',
#   'insur',
#   'list',
#   'wfd',
#   'paye',
#   'event',
#   'loss'],
#  ['resubmit', 'proof', 'maintain', 'insur', 'vehicl', 'via', 'wfd', 'websit'],
#  ['began',
#   'receiv',
#   'multipl',
#   'phone',
#   'call',
#   'per',
#   'day',
#   'wfd',
#   'attempt',
#   'collect',
#   'debt',
#   'maintain',
#   'insur',
#   'thi',
#   'vehicl'],
#  ['third', 'time', 'resubmit', 'proof', 'insur', 'well', 'letter', 'wfd'],
#  ['sinc', 'thi', 'time', 'receiv', 'respons', 'write'],
#  ['phone', 'call', 'collect', 'debt', 'owe', 'continu'],
#  ['thi',
#   'debt',
#   'collector',
#   'attempt',
#   'collect',
#   'debt',
#   'onli',
#   'liabl',
#   'accord',
#   'nevada',
#   'protect',
#   'victim'],
#  ['2011', 'move', 'thi', 'apart', 'share', 'fianc'],
#  ['wa', 'victim', 'leav', 'state', 'safeti'],
#  ['accord', 'nevada', 'landlordten', 'law', 'nev', 'rev'],
#  ['stat'],
#  ['ann'],
#  ['118a345',
#   '118a347',
#   '118a510',
#   'right',
#   'break',
#   'leas',
#   'agreement',
#   'ive',
#   'victim'],
#  ['exercis',
#   'right',
#   'obtain',
#   'order',
#   'protect',
#   'notifi',
#   'landlord',
#   'move',
#   'right',
#   'away'],
#  ['never', 'knew', 'thi', 'debt', 'recent', 'pop', 'credit', 'report'],
#  ['discov',
#   'card',
#   'someon',
#   'open',
#   'secur',
#   'card',
#   'name',
#   'never',
#   'author',
#   'wont',
#   'remov'],
#  ['previous',
#   'file',
#   'complaint',
#   'wa',
#   'disput',
#   'ha',
#   'resolut',
#   'file',
#   'thi',
#   'complaint'],
#  ['loan', 'key', 'bank', 'absolut', 'worst', 'compani', 'ever', 'work'],
#  ['student',
#   'loan',
#   'elsewher',
#   'current',
#   'custom',
#   'key',
#   'bank',
#   'far',
#   'outpac',
#   'ani',
#   'compani',
#   'worst',
#   'compani',
#   'deal'],
#  ['tri',
#   'lower',
#   'payment',
#   'long',
#   'time',
#   'thi',
#   'point',
#   'becaus',
#   'afford',
#   'ridicul',
#   'payment',
#   '45000',
#   'right'],
#  ['onli',
#   'afford',
#   '15000',
#   'month',
#   'desper',
#   'want',
#   'make',
#   'payment',
#   'ha',
#   'made',
#   'work',
#   'third',
#   'compani',
#   'ha',
#   'restrict',
#   'number',
#   'becaus',
#   'shadi'],
#  ['alreadi',
#   'use',
#   'one',
#   'compani',
#   'take',
#   'care',
#   'loan',
#   'key',
#   'loan',
#   'hire',
#   'anoth',
#   'compani',
#   'sole',
#   'respons',
#   'call',
#   '5',
#   'time',
#   'day',
#   'harass'],
#  ['thi',
#   'compani',
#   'predatori',
#   'practic',
#   'beyond',
#   'ridicul',
#   'thi',
#   'point'],
#  ['want',
#   'pay',
#   'loan',
#   'eventu',
#   'higher',
#   'pay',
#   'job',
#   'wife',
#   'higher',
#   'pay',
#   'job',
#   'nt',
#   'abil',
#   'afford',
#   'payment',
#   'right'],
#  ['like',
#   'mani',
#   'student',
#   'feel',
#   'like',
#   'wa',
#   'taken',
#   'advantag',
#   'whenev',
#   'went',
#   'school',
#   'wa',
#   'told',
#   'would',
#   'harass',
#   'constantli',
#   'would',
#   'pay',
#   'half',
#   'one',
#   'paycheck',
#   'month',
#   'student',
#   'loan',
#   'compani'],
#  ['incom',
#   'allow',
#   'pay',
#   'loan',
#   'key',
#   'bank',
#   'doe',
#   'care',
#   'peopl',
#   'ha',
#   'proven',
#   'everi',
#   'time',
#   'call'],
#  ['pleas',
#   'someon',
#   'help',
#   'actual',
#   'abl',
#   'pay',
#   'loan',
#   'prevent',
#   'thi',
#   'compani',
#   'attempt',
#   'take',
#   'ruin',
#   'life'],
#  ['thank', 'ani', 'help'],
#  ['access',
#   'capit',
#   'one',
#   'credit',
#   'card',
#   'site',
#   'internet',
#   'pay',
#   'monthli',
#   'bill',
#   'alway',
#   'done',
#   'number',
#   'question',
#   'tri',
#   'get',
#   'updat',
#   'incom'],
#  ['allow', 'bypass', 'pay', 'bill'],
#  ['call', 'complain', 'agre', 'take'],
#  ['today',
#   'tri',
#   'access',
#   'account',
#   'pay',
#   'question',
#   'came',
#   'allow',
#   'bypass'],
#  ['nt', 'want', 'updat', 'statu'],
#  ['process',
#   'pay',
#   'thi',
#   'credit',
#   'card',
#   'balanc',
#   '160000',
#   'limit',
#   '330000'],
#  ['thi',
#   'amount',
#   'harass',
#   'onli',
#   'want',
#   'quickli',
#   'pay',
#   'internet',
#   'oppos',
#   'pay',
#   'phone',
#   'longer',
#   'process'],
#  ['call', 'phone', 'alway', 'long', 'wait', 'time'],
#  ['deliber', 'caus', 'wast', 'time', 'becaus', 'know', 'pay'],
#  ['wonder',
#   'tri',
#   'get',
#   'pay',
#   'mail',
#   'would',
#   'make',
#   'payment',
#   'late',
#   'entitl',
#   'ridicul',
#   'late',
#   'payment',
#   'fee',
#   '3500'],
#  ['credit', 'score', 'superb', 'custom', 'year'],
#  ['thi', 'uncal', 'harass', 'want', 'stop'],
#  ['hello',
#   'social',
#   'secur',
#   'veteran',
#   'social',
#   'secur',
#   'deal',
#   'card',
#   'comerica',
#   'bank',
#   'money',
#   'direct',
#   'deposit'],
#  ['money',
#   'ha',
#   'disappear',
#   'account',
#   'sever',
#   'time',
#   'file',
#   'disput',
#   '12',
#   'hour',
#   'phone',
#   'bank',
#   'employe'],
#  ['sever', 'lie', 'record', 'told', 'wa', 'hack'],
#  ['miss',
#   'dollar',
#   'friday',
#   'account',
#   'wa',
#   'drain',
#   'call',
#   'made',
#   'awar',
#   'wa',
#   'nt',
#   'comerica',
#   'bank',
#   'supervisor',
#   'said',
#   'wait',
#   'let',
#   'stolen',
#   'file',
#   'disput'],
#  ['anoth', 'employe', 'state', 'manag', 'wa', 'lazi', 'stop', 'payment'],
#  ['bank', 'refus', 'send', 'statement', 'day', 'one'],
#  ['refus', 'allow', 'file', 'disput'],
#  ['internet',
#   'say',
#   'comerica',
#   'bank',
#   'wa',
#   'hack',
#   'wo',
#   'nt',
#   'tell',
#   'costum'],
#  ['thi',
#   'insid',
#   'job',
#   'everi',
#   'card',
#   'issu',
#   'stole',
#   'befor',
#   'even',
#   'use'],
#  ['put', 'dollar', 'back', 'card', 'want', 'go', 'away'],
#  ['want',
#   'full',
#   'investig',
#   'account',
#   'bank',
#   'respons',
#   'money',
#   'stolen',
#   'refus',
#   'help'],
#  ['thi',
#   'grand',
#   'larceni',
#   'commit',
#   'sever',
#   'state',
#   'fbi',
#   'matter',
#   'also',
#   'live',
#   'ohio',
#   'card',
#   'wa',
#   'use',
#   'unit',
#   'state',
#   'friday'],
#  ['phone', 'compani', 'money', 'wa', 'stolen'],
#  ['close',
#   'account',
#   'switch',
#   'bank',
#   'never',
#   'recov',
#   'money',
#   'onli',
#   'talk',
#   'costum'],
#  ['help', 'pleas'],
#  ['issu', 'capit', 'one', 'close', 'case', 'without', 'permiss'],
#  ['someon',
#   'call',
#   'execut',
#   'offic',
#   'call',
#   'back',
#   'sever',
#   'time',
#   'never',
#   'respond'],
#  ['work', 'lower', 'monthli', 'payment', 'thi', 'hardship'],
#  ['job', 'refus', 'budg'],
#  ['account', 'default'],
#  ['appli',
#   'cours',
#   'request',
#   'cancel',
#   'cours',
#   'next',
#   'day',
#   'wa',
#   'told',
#   'cancel',
#   'cours',
#   'told',
#   '3',
#   'day',
#   'right',
#   'refus'],
#  ['wa', 'told', 'nt', 'appli', 'cours'],
#  ['never',
#   'log',
#   'cours',
#   'use',
#   'cours',
#   'charg',
#   '200000',
#   'use',
#   'receiv',
#   'cours',
#   'work'],
#  ['feel', 'forc', 'use', 'product'],
#  ['nt',
#   'ani',
#   'judgement',
#   'md',
#   'amount',
#   '270000',
#   'state',
#   'credit',
#   'report',
#   'report'],
#  ['seller',
#   'properti',
#   'ca',
#   'accept',
#   'offer',
#   'sell',
#   'mobil',
#   'home',
#   'land',
#   'open',
#   'escrow'],
#  ['sinc',
#   'wa',
#   'mortgag',
#   'home',
#   'origin',
#   'sold',
#   'chase',
#   'bank',
#   'escrow',
#   'request',
#   'pay',
#   'amount',
#   'condit',
#   'lien',
#   'releas',
#   'chase',
#   'bank',
#   '2016',
#   'per',
#   'california',
#   'dept'],
#  ['hous', 'commun', 'develop', 'hcd', 'requir'],
#  ['dozen',
#   'request',
#   'phone',
#   'call',
#   'later',
#   'still',
#   'condit',
#   'lien',
#   'releas'],
#  ['chase',
#   'inabl',
#   'provid',
#   'simpl',
#   'condit',
#   'lien',
#   'releas',
#   'jeopard',
#   'seller',
#   'abil',
#   'secur',
#   'perman',
#   'new',
#   'home',
#   'live',
#   'current',
#   'live',
#   'friend',
#   'buyer',
#   'desir',
#   'thi',
#   'properti'],
#  ['last',
#   'contact',
#   'chase',
#   'bank',
#   'wa',
#   'senior',
#   'servic',
#   'rep',
#   'escal',
#   'ext'],
#  [],
#  ['chase', 'loan'],
#  ['collect',
#   'wa',
#   'report',
#   'experian',
#   'without',
#   'knowledg',
#   'receiv',
#   'verif',
#   'letter'],
#  ['violat', 'fcra', 'right'],
#  ['origin', 'debt', 'wa', 'paid', '2014'],
#  ['read', 'class', 'action', 'suit', 'navient', 'formerli'],
#  ['would',
#   'like',
#   'stay',
#   'inform',
#   'believ',
#   'victim',
#   'misinform',
#   'decept',
#   'around',
#   'repay',
#   'option'],
#  ['graduat', '1995', 'ye', '1995', '23', 'year', 'ago'],
#  ['paid',
#   'loan',
#   'year',
#   'howev',
#   'variou',
#   'time',
#   'ran',
#   'financi',
#   'difficulti',
#   'job',
#   'layoff',
#   'children',
#   'could',
#   'work',
#   'simpli',
#   'financi',
#   'hardship'],
#  ['interest',
#   'charg',
#   'accumul',
#   'much',
#   'variou',
#   'forebear',
#   'suggest',
#   'today',
#   'balanc',
#   'due',
#   'origin',
#   'loan',
#   'amount'],
#  ['owe', 'today', 'amount', 'borrow', '23', 'year', 'ago'],
#  ['time',
#   'time',
#   'call',
#   'discuss',
#   'financi',
#   'hardship',
#   'wa',
#   'immedi',
#   'push',
#   'toward',
#   'forbear'],
#  ['time',
#   'wa',
#   'told',
#   'wa',
#   'option',
#   'lower',
#   'payment',
#   'push',
#   'abl',
#   'find',
#   'plan'],
#  ['wa',
#   'told',
#   'elig',
#   'ani',
#   'type',
#   'loan',
#   'forgiv',
#   'part',
#   'incom',
#   'sensit',
#   'repay',
#   'plan',
#   'even',
#   'im',
#   '25',
#   'year',
#   'thi',
#   'program',
#   'elig',
#   'loan',
#   'forgiv'],
#  ['claim',
#   'bancruptci',
#   '10',
#   'year',
#   'ago',
#   'wa',
#   'told',
#   'could',
#   'includ',
#   'student',
#   'loan'],
#  ['die', 'someday', 'thi', 'student', 'loan', 'debt'],
#  ['never', 'pay'],
#  ['current', 'incom', 'sensit', 'repay', 'plan', 'renew', 'yearli'],
#  ['read',
#   'articl',
#   'realli',
#   'hit',
#   'home',
#   'hope',
#   'thiev',
#   'ultim',
#   'one',
#   'lose',
#   'contribut',
#   'stress',
#   'anxieti',
#   'mani',
#   'suffer',
#   'due',
#   'debt',
#   'suffoc',
#   'execut',
#   'collect',
#   'dollar',
#   'bonu',
#   'check',
#   'compris',
#   'hard',
#   'work',
#   'bill',
#   'pay',
#   'american',
#   'citizen'],
#  ['inquir',
#   'origin',
#   'creditor',
#   'thi',
#   'old',
#   'account',
#   'state',
#   'longer',
#   'report',
#   'thi',
#   'account',
#   'credit',
#   'report',
#   'thu',
#   'disput',
#   'request',
#   'delet',
#   'thi',
#   'bureau',
#   'directli'],
#  ['howev',
#   'numer',
#   'attempt',
#   'get',
#   'thi',
#   'account',
#   'delet',
#   'experian',
#   'report',
#   'even',
#   'suppli',
#   'letter',
#   'creditor',
#   'directli',
#   'state',
#   'report',
#   'thi',
#   'credit',
#   'report',
#   'anymor'],
#  ['phone',
#   'call',
#   'wast',
#   'time',
#   'wa',
#   'never',
#   'abl',
#   'get',
#   'ahold',
#   'anyon',
#   'hour',
#   'hold'],
#  ['websit',
#   'unrespons',
#   'keep',
#   'get',
#   'auto',
#   'gener',
#   'mail',
#   'experian',
#   'state',
#   'verifi',
#   'thi',
#   'acount',
#   'howev',
#   'state',
#   'verifi',
#   'ani',
#   'inform',
#   'thi',
#   'nonexist',
#   'delet',
#   'account'],
#  ['bank',
#   'account',
#   'wa',
#   'charg',
#   'overdraft',
#   'fee',
#   'onli',
#   'one',
#   'charg'],
#  ['payment', 'post', 'account', '15'],
#  ['9400', '1700', '1000'],
#  ['howev',
#   'suntrust',
#   'post',
#   'largest',
#   'payment',
#   'first',
#   'caus',
#   'account',
#   'go',
#   '100',
#   'proceed',
#   'post',
#   'payment'],
#  ['becaus', 'thi', 'overdraft', 'fee', 'chang'],
#  ['smaller',
#   'payment',
#   'would',
#   'post',
#   'first',
#   'onli',
#   'overdraft',
#   'fee',
#   'would',
#   'charg'],
#  ['contact',
#   'state',
#   'wa',
#   'polici',
#   'post',
#   'largest',
#   'payment',
#   'first',
#   'even',
#   'though',
#   'may',
#   'caus',
#   'extra',
#   'overdraft',
#   'fee',
#   'charg'],
#  ['addit', 'said', 'wa', 'polici', 'onli', 'refund', 'overdraft', 'fee'],
#  ['thi',
#   'abus',
#   'polici',
#   'onli',
#   'place',
#   'inflect',
#   'maximum',
#   'number',
#   'overdraft',
#   'fee'],
#  ['said',
#   'wa',
#   'import',
#   'thing',
#   'paid',
#   'wa',
#   'case',
#   'item',
#   'paid',
#   'becaus',
#   'account',
#   'wa',
#   'overdrawn'],
#  ['suntrust',
#   'allow',
#   'polici',
#   'onli',
#   'place',
#   'caus',
#   'signific',
#   'number',
#   'overdraft',
#   'fee',
#   'account',
#   'goe',
#   'neg'],
#  ['2018', 'student', 'loan', 'acquir', 'nelnet'],
#  ['nelnet', 'took', 'feder', 'subsid', 'loan', 'privat', 'loan'],
#  ['appear', 'divis', 'entiti', 'conglomer'],
#  ['time', 'loan', 'acquisit', 'alreadi', 'render', 'monthli', 'payment'],
#  ['seem', 'receiv', 'transfer', 'payment', 'netnet', 'ha'],
#  ['nelnet',
#   'account',
#   'show',
#   'current',
#   'account',
#   'ha',
#   'shown',
#   'incorrect',
#   'delinqu',
#   'sinc',
#   'transfer'],
#  ['two',
#   'divis',
#   'entiti',
#   'conglomer',
#   'commun',
#   'one',
#   'anoth',
#   'resolv',
#   'thi'],
#  ['call',
#   'sever',
#   'time',
#   'well',
#   'sent',
#   'statement',
#   'payment',
#   'made',
#   'twice'],
#  ['custom',
#   'servic',
#   'unhelp',
#   'condescend',
#   'issu',
#   'payment',
#   'made',
#   'credit',
#   'properli',
#   'keep',
#   'receiv',
#   'factual',
#   'erron',
#   'delinqu',
#   'notic',
#   'correspond',
#   'indic',
#   'account',
#   'refer',
#   'collect'],
#  ['loan',
#   'transfer',
#   'nelnet',
#   'wa',
#   'without',
#   'consent',
#   'ha',
#   'result',
#   'higher',
#   'interest',
#   'rate',
#   'top',
#   'thi',
#   'monthli',
#   'erron',
#   'delinqu',
#   'notic'],
#  ['ask',
#   'us',
#   'bank',
#   'home',
#   'mortgag',
#   'help',
#   'wa',
#   '3',
#   'month',
#   'behind',
#   'mortgag',
#   'result',
#   'incom',
#   'unemploy',
#   'dure',
#   'month'],
#  ['request',
#   'assist',
#   'result',
#   'offer',
#   'pay',
#   'increas',
#   'monthli',
#   'payment',
#   'includ',
#   'month',
#   'document',
#   'month',
#   'unemploy'],
#  ['reject',
#   'offer',
#   'pay',
#   'money',
#   'dure',
#   'month',
#   'continu',
#   'pay',
#   'mortgag',
#   'dure',
#   'decis',
#   'process'],
#  ['continu',
#   'payment',
#   'left',
#   'owe',
#   'onli',
#   'one',
#   'month',
#   'past',
#   'due',
#   'includ',
#   'late',
#   'fee'],
#  ['howev',
#   'us',
#   'bank',
#   'refus',
#   'accept',
#   'full',
#   'mortgag',
#   'payment',
#   'amount',
#   'origin',
#   'payment',
#   'befor',
#   'mortgag',
#   'assist',
#   'offer',
#   'start'],
#  ['make',
#   'thi',
#   'payment',
#   'would',
#   'bring',
#   'account',
#   'current',
#   'howev',
#   'refus',
#   'accept'],
#  ['wa', 'refus', 'return', 'bank', 'automat', 'bill', 'pay'],
#  ['accept',
#   'full',
#   'monthli',
#   'payment',
#   'account',
#   'would',
#   'late',
#   '30',
#   'day'],
#  ['addit', 'offer', 'assist', 'plan', 'doe', 'start'],
#  ['refus',
#   'offer',
#   'sinc',
#   'includ',
#   'make',
#   'payment',
#   'dure',
#   'month',
#   'incom'],
#  ['addit',
#   'disappoint',
#   'us',
#   'bank',
#   'offer',
#   'becaus',
#   'pursu',
#   'evid',
#   'incom',
#   '9',
#   'month',
#   'ignor',
#   'investig',
#   'also',
#   'refus',
#   'help',
#   'address',
#   '100000',
#   'late',
#   'fee'],
#  ['thi', 'wa', 'help', 'could', 'receiv', 'without', '6', 'month', 'wait'],
#  ['could', 'achiev', 'offer', 'one', 'phone', 'call'],
#  ['sent',
#   'letter',
#   'tell',
#   'us',
#   'bank',
#   'home',
#   'mortgag',
#   'want',
#   'accept',
#   'offer',
#   'help',
#   'abov',
#   'reason'],
#  ['2016',
#   'exact',
#   'day',
#   'unk',
#   'made',
#   'onlin',
#   'purchas',
#   'taser',
#   'holster'],
#  ['purchas',
#   'wa',
#   'take',
#   'long',
#   'arriv',
#   'contact',
#   'compani',
#   'statu',
#   'purchas'],
#  ['contact', 'compani', 'via', 'email', 'time', 'respons'],
#  ['date', 'follow', '2016', '2016', '2016', '2016'],
#  ['last',
#   'date',
#   'ask',
#   'complet',
#   'refund',
#   'becaus',
#   'wa',
#   'get',
#   'run',
#   'around'],
#  ['typic',
#   'made',
#   'ani',
#   'purchas',
#   'onlin',
#   'charg',
#   'item',
#   'get',
#   'ship',
#   'found',
#   'strang',
#   'thi',
#   'compani'],
#  ['commun', 'broke', 'request', 'refund'],
#  ['contact',
#   'master',
#   'card',
#   'issu',
#   'barclaycard',
#   '2016',
#   'disput',
#   'charg',
#   'suppli',
#   'email',
#   'receipt',
#   'transact',
#   'wa',
#   'given',
#   'case',
#   'number',
#   'told',
#   'would',
#   'take',
#   '90',
#   'day',
#   'get',
#   'resolv'],
#  ['hear',
#   'back',
#   'barclaycard',
#   'contact',
#   '2016',
#   'wa',
#   'told',
#   'case',
#   'ha',
#   'resolv',
#   '2016'],
#  ['2016',
#   'recontact',
#   'barclaycard',
#   'wa',
#   'told',
#   'disput',
#   'charg',
#   'reflect',
#   'within',
#   '48',
#   'hour'],
#  ['2016',
#   'spoke',
#   'barclaycard',
#   'regard',
#   'disput',
#   'wa',
#   'told',
#   'wa',
#   'error',
#   'wa',
#   'given',
#   'new',
#   'case',
#   'number'],
#  ['contact',
#   'credit',
#   'card',
#   '2016',
#   'wa',
#   'told',
#   'would',
#   'take',
#   '45',
#   'day',
#   '2016',
#   'hear',
#   'back',
#   'merchant'],
#  ['seem',
#   'onc',
#   'get',
#   'run',
#   'around',
#   'thi',
#   'time',
#   'credit',
#   'card',
#   'thi',
#   'disput',
#   'wa',
#   'first',
#   'report',
#   'credit',
#   'card',
#   'begin',
#   '2016'],
#  ['claim',
#   'dept',
#   'claim',
#   'initi',
#   'claim',
#   'chang',
#   'debit',
#   'card',
#   'due',
#   'issu'],
#  ['im', 'seller', 'sinc'],
#  ['updat',
#   'new',
#   'debit',
#   'card',
#   'site',
#   'took',
#   'card',
#   'replac',
#   'check',
#   'acct',
#   'make',
#   'payment',
#   'monthli',
#   'seller',
#   'fee',
#   'end',
#   'month',
#   'know',
#   'thi'],
#  ['mid', 'month', 'account', 'wa', 'debit', '13000'],
#  ['recogn', 'thi'],
#  ['call', 'boa', 'immedi', 'advis'],
#  ['stop', 'card', 'end', 'gave', 'temp', 'credit', '13000'],
#  ['account'],
#  ['wa', 'holiday', 'weekend'],
#  ['time',
#   'wa',
#   'abl',
#   'get',
#   'bottom',
#   'thi',
#   'find',
#   'charg',
#   'new',
#   'debit',
#   'card',
#   'seller',
#   'fee',
#   'given',
#   'credit',
#   '59',
#   'hurrican',
#   'irma'],
#  ['amount', 'monthli', 'fee', '13000'],
#  ['also',
#   'told',
#   'debit',
#   'card',
#   'mid',
#   'month',
#   'cking',
#   'acct',
#   'end',
#   'month',
#   'bill',
#   'seller',
#   'fee'],
#  ['notifi', 'boa', 'advis', 'issu', 'resolv'],
#  ['state', 'merchant', 'got', 'paid', '13000'],
#  ['go', 'take', 'temp', 'credit', 'acct', 'end'],
#  ['never', 'took', 'back'],
#  ['call',
#   'n',
#   'boa',
#   'phone',
#   'boa',
#   'gave',
#   'money',
#   'back',
#   'state',
#   'take',
#   'cking'],
#  ['boa',
#   'never',
#   'took',
#   'cking',
#   'acct',
#   'anoth',
#   'nasti',
#   'notic',
#   'took',
#   'back'],
#  ['im', 'past', 'furiou'],
#  ['want',
#   'suspend',
#   'acct',
#   'non',
#   'pymt',
#   'ive',
#   'seller',
#   'sinc',
#   'depend',
#   'thi',
#   'incom'],
#  ['cost', 'time'],
#  ['gave', 'back', 'money'],
#  ['final',
#   'take',
#   'money',
#   'cking',
#   'acct',
#   'get',
#   'letter',
#   'state',
#   'case',
#   'close'],
#  ['yay'],
#  ['fast', 'forward'],
#  ['notifi', 'come', 'take'],
#  ['credit', 'charg', 'back', 'omg', '13000'],
#  ['im', 'upset'],
#  ['enough'],
#  ['call',
#   'boa',
#   'immedi',
#   'claim',
#   'dept',
#   'phone',
#   'guy',
#   'help',
#   '1st',
#   'thing',
#   'thi',
#   '48',
#   'hr',
#   'escal'],
#  ['cant', 'talk', 'dept'],
#  ['thi', 'afternoon', 'suspendedblock', 'account', 'non', 'payment'],
#  ['call', 'boa', 'spoke', 'suppos', 'supv', 'claim', 'dept', 'id'],
#  ['help', 'refus', 'take', 'ref', 'transact', 'charg', 'back', 'rep'],
#  ['wa', 'astonish'],
#  ['deni', 'flatli', 'took', 'money', 'show', 'everyth', 'even', 'side'],
#  ['state', 'wa', 'error', '710day', 'send', 'back'],
#  ['3rd',
#   'time',
#   'charg',
#   'back',
#   'dont',
#   'blame',
#   'said',
#   'cant',
#   'unlock',
#   'suspens',
#   'pay',
#   'full',
#   '13000',
#   'normal',
#   'monthli',
#   'charg',
#   'due',
#   '164',
#   'borrow',
#   'pay',
#   '30000',
#   'get',
#   'account',
#   'back',
#   'sell'],
#  ['im',
#   'waitin',
#   'g',
#   'review',
#   'see',
#   'let',
#   'continu',
#   'sell',
#   'due',
#   'thi',
#   'mess',
#   'claim',
#   'dept',
#   'boa'],
#  ['fire'],
#  ['want',
#   '13000',
#   'back',
#   '8',
#   'hr',
#   '25',
#   'hr',
#   'phone',
#   'sent',
#   'away',
#   'job',
#   'tri',
#   'resolv',
#   'thi'],
#  ['demand', 'back', 'letter', 'apolog', 'also', 'employ', 'mess', 'creat'],
#  ['got', 'resolv', 'bounc', 'place', 'place', 'horribl', 'servic', 'fl'],
#  ['collect',
#   'state',
#   'colorado',
#   'child',
#   'support',
#   'kid',
#   'adult',
#   'pay',
#   'monthli',
#   '20',
#   'year',
#   'late',
#   'payment'],
#  ['credit',
#   'report',
#   'report',
#   'balanc',
#   'collect',
#   'state',
#   'colorado',
#   'everi',
#   'time',
#   'tri',
#   'call',
#   'record',
#   'tri',
#   'disput',
#   'item',
#   'experian',
#   'remov',
#   'come',
#   'back',
#   'verifi'],
#  ['never', 'collect', 'still', 'pay', 'adult', 'children'],
#  ['affect',
#   'abil',
#   'get',
#   'home',
#   'loan',
#   'thi',
#   'item',
#   'still',
#   'credit',
#   'report'],
#  ['need', 'help', 'get', 'remov', 'item', 'credit', 'report', 'experian'],
#  ['bureau', 'remov', 'item', 'report'],
#  ['got',
#   'sever',
#   'call',
#   'well',
#   'fargo',
#   'regard',
#   'late',
#   'payment',
#   'payment',
#   'wa',
#   'late',
#   'receiv',
#   'took',
#   'payment',
#   'appli',
#   'princip',
#   'cancel',
#   'check',
#   'proceed',
#   'say',
#   'wa',
#   '31',
#   'day',
#   'late',
#   'know',
#   'manag',
#   'money',
#   'women',
#   'name',
#   'wa',
#   'rude',
#   'abras',
#   'issu',
#   'wa',
#   'resolv',
#   'wa',
#   'call',
#   'next',
#   'day',
#   'treat',
#   'way',
#   'wa',
#   'error',
#   'still',
#   'call',
#   'would',
#   'never',
#   'want',
#   'anyon',
#   'treat',
#   'thi',
#   'way'],
#  ['2018',
#   'agre',
#   'well',
#   'fargo',
#   'bank',
#   'close',
#   'debit',
#   'visa',
#   'card',
#   'due',
#   'fradul',
#   'transact'],
#  ['wa', 'issu', 'new', 'debt', 'visa', 'card', '1', 'week', 'later'],
#  ['give', 'ani', 'compani', 'new', 'debit', 'visa', 'card', 'inform'],
#  ['2018',
#   'charg',
#   'old',
#   'card',
#   'reoccur',
#   'payment',
#   'charg',
#   'went',
#   'account',
#   'although',
#   'suppli',
#   'new',
#   'card',
#   'inform'],
#  ['went',
#   'account',
#   'well',
#   'well',
#   'fargo',
#   'account',
#   'reflect',
#   'number',
#   'old',
#   'debt',
#   'visa',
#   'card',
#   'wa',
#   'close'],
#  ['call', 'well', 'fargo', 'said', 'wa', 'issu', 'due', 'agreement'],
#  ['call',
#   'said',
#   'need',
#   'contact',
#   'well',
#   'fargo',
#   'becaus',
#   'one',
#   'allow',
#   'old',
#   'card',
#   'number',
#   'charg',
#   'prevent',
#   'interrupt',
#   'servic'],
#  ['past',
#   'debt',
#   'visa',
#   'card',
#   'wa',
#   'cancelledclos',
#   'merchant',
#   'would',
#   'unabl',
#   'charg',
#   'account',
#   'would',
#   'updat',
#   'give',
#   'new',
#   'card',
#   'inform',
#   'want',
#   'continu',
#   'servic'],
#  ['grave',
#   'concern',
#   'protect',
#   'fraud',
#   'merchant',
#   'still',
#   'receiv',
#   'payment',
#   'check',
#   'account',
#   'use',
#   'closedcancel',
#   'debt',
#   'card'],
#  ['well', 'fargo', 'would', 'give', 'option', 'prevent', 'thi', 'happen'],
#  ['therefor', 'cancel', 'new', 'debit', 'card', 'concern'],
#  ['money',
#   '350000',
#   'wa',
#   'transfer',
#   'boa',
#   'account',
#   'daughter',
#   'account',
#   'without',
#   'author'],
#  ['wa',
#   'overs',
#   'account',
#   'access',
#   'account',
#   'permiss',
#   'use',
#   'account',
#   'ani',
#   'mannerth',
#   'money',
#   'wa',
#   'taken',
#   '5',
#   'differ',
#   'atm',
#   'az'],
#  ['file', 'fraud', 'claim', 'boa', 'wa', 'deni'],
#  ['call',
#   'back',
#   'sinc',
#   'reopen',
#   'thi',
#   'case',
#   'give',
#   'time',
#   'frame',
#   'get',
#   'money',
#   'back'],
#  ['thi', 'wire', 'fraud'],
#  ['told', 'devic', 'use', 'wa', 'phone'],
#  ['bought', 'honda', 'fit'],
#  ['credit',
#   'wasnt',
#   'good',
#   'stand',
#   'due',
#   'unemploy',
#   'therefor',
#   'someon',
#   'cosign',
#   'loan',
#   'could',
#   'get',
#   'loan',
#   'lower',
#   'interest',
#   'rate'],
#  ['veri',
#   'clear',
#   'state',
#   'onc',
#   'cosign',
#   'relat',
#   'put',
#   'titl',
#   'registr',
#   'becaus',
#   'ha',
#   'hi',
#   'vehicl',
#   'due',
#   'previou',
#   'would',
#   'remov'],
#  ['didnt', 'want', 'upset'],
#  ['howev', 'dealership', 'actual', 'put', 'first', 'titl'],
#  ['put', 'money', 'vehicl', 'im', 'make', 'payment'],
#  ['total', 'car'],
#  ['didnt',
#   'know',
#   'honda',
#   'done',
#   'thi',
#   'mid',
#   'dmv',
#   'sent',
#   'cosign',
#   'letter'],
#  ['dmv', 'said', 'till', 'remov', 'hi', 'name', 'titl'],
#  ['done', 'everyth', 'ask', 'us', 'chang', 'thi'],
#  ['wa',
#   'notifi',
#   'honda',
#   'financi',
#   'servic',
#   'notor',
#   'letter',
#   'ask',
#   'remov',
#   'titl',
#   'registr'],
#  ['said', 'hf', 'even', 'submit', 'paperwork', 'time', 'wa'],
#  ['resubmit',
#   'anoth',
#   'letter',
#   'hf',
#   'becaus',
#   'entir',
#   'happi',
#   'word',
#   'first',
#   'letter'],
#  ['thi', 'point', 'wa', 'way', 'would', 'get', 'chang', 'befor', 'deadlin'],
#  ['cosign',
#   'ha',
#   'call',
#   'dmv',
#   'sinc',
#   'hf',
#   'still',
#   'ha',
#   'complet',
#   'titl',
#   'registr',
#   'chang'],
#  ['dure',
#   'thi',
#   'time',
#   'cosign',
#   'ha',
#   'hi',
#   'licens',
#   'revok',
#   'becaus',
#   'hi',
#   'name',
#   'titl',
#   'registr',
#   'car'],
#  ['cosign',
#   'know',
#   'drive',
#   'vehichl',
#   'without',
#   'therefor',
#   'tri',
#   'make',
#   'veri',
#   'clear',
#   'purchas',
#   'car',
#   'wa',
#   'mine',
#   'entir',
#   'hi',
#   'wa',
#   'onli',
#   'driver'],
#  ['cosign', 'wa', 'mere', 'tri', 'help'],
#  ['cost',
#   'us',
#   'money',
#   'becaus',
#   'im',
#   'sure',
#   'legal',
#   'drive',
#   'car',
#   'becaus',
#   'issu',
#   'purchas',
#   'rental'],
#  ['tuesday', 'call', 'hf', 'noth', 'ha', 'chang'],
#  ['dmv', 'told', 'cosign', 'hf', 'wa', 'suppos', 'submit', 'electron', 'titl'],
#  ['rep',
#   'spoke',
#   'said',
#   'would',
#   'call',
#   'dmv',
#   'next',
#   'morn',
#   'see',
#   'need',
#   'cosign',
#   'call',
#   'next',
#   'day',
#   'noth',
#   'chang',
#   'call',
#   'hf',
#   'one',
#   'knew',
#   'anyth',
#   'proceed',
#   'tell',
#   'us',
#   'need',
#   'titl',
#   'registr',
#   'chang'],
#  ['told',
#   'rep',
#   'done',
#   'thing',
#   'wait',
#   'explain',
#   'convers',
#   'rep',
#   'would',
#   'call',
#   'dmv',
#   'morn'],
#  ['check', 'said', 'rep', 'wa', 'day'],
#  ['said', 'didnt', 'know', 'anyth', 'end'],
#  ['contact',
#   'dmv',
#   'onlin',
#   'even',
#   'respons',
#   'wa',
#   'hf',
#   'lien',
#   'holder',
#   'familiar',
#   'electron',
#   'process',
#   'everyth',
#   'need',
#   'submit'],
#  ['made',
#   'mani',
#   'phone',
#   'call',
#   'hf',
#   'given',
#   'everyth',
#   'ask',
#   'arent',
#   'get',
#   'ani'],
#  ['howev',
#   'spend',
#   'money',
#   'tri',
#   'rental',
#   'drive',
#   'cosign',
#   'becaus',
#   'isnt',
#   'allow',
#   'drive',
#   'hi',
#   'car',
#   'sinc',
#   'hi',
#   'licens',
#   'ha',
#   'revok',
#   'due',
#   'fact',
#   'honda',
#   'dealership',
#   'nc',
#   'wa',
#   'dishonest',
#   'uneth'],
#  ['give', 'copi', 'ani', 'transact', 'day', 'purchas', 'car'],
#  ['appli', 'credit', 'card'],
#  ['deni', 'base', 'allegedli', 'zero', 'credit', 'histori'],
#  ['credit', 'wa', 'pull'],
#  ['insist', 'wa', 'done', 'properli'],
#  ['extens', 'credit', 'histori', 'sinc', '1993'],
#  ['obvious',
#   'thi',
#   'scamrefus',
#   'help',
#   'insist',
#   'right',
#   'everyth',
#   'wrong'],
#  ['told', 'go', 'anoth', 'bank'],
#  ['credit', 'card', 'offer', 'barclay', 'bank'],
#  ['never',
#   'author',
#   'automat',
#   'renew',
#   'membership',
#   'charg',
#   'credit',
#   'card'],
#  ['barclay',
#   'bank',
#   'charg',
#   '2500',
#   'automat',
#   'renew',
#   'fee',
#   'refus',
#   'issu',
#   'refund'],
#  ['thi', 'car', 'wa', 'fraud'],
#  ['occasion',
#   'well',
#   'fargo',
#   'ha',
#   'fail',
#   'mail',
#   'us',
#   'monthli',
#   'payment',
#   'coupon'],
#  ['previous',
#   'thi',
#   'ha',
#   'creat',
#   'problem',
#   'simpli',
#   'mail',
#   'payment',
#   'address',
#   'list',
#   'previou',
#   'coupon'],
#  ['wa', 'first', 'time', 'receiv', 'payment', 'coupon'],
#  ['whether', 'thi', 'wa', 'done', 'intent', 'inadvert', 'say'],
#  ['howev',
#   'well',
#   'fargo',
#   'send',
#   'coupon',
#   'certifi',
#   'consequ',
#   'well',
#   'fargo',
#   'claim',
#   'certainti',
#   'coupon',
#   'wa',
#   'sent',
#   'receiv'],
#  ['nevertheless',
#   'without',
#   'coupon',
#   'mail',
#   'payment',
#   'well',
#   'fargo',
#   'time',
#   'envelop',
#   'use',
#   'us',
#   'mail'],
#  ['done', 'thi', 'befor', 'without', 'problem'],
#  ['send', 'certifi', 'think'],
#  ['well', 'fargo', 'receiv', 'due', 'assum', 'wa', 'postal', 'error'],
#  ['envelop', 'came', 'back', 'us', 'around'],
#  ['indic', 'well', 'fargo', 'receiv', 'payment'],
#  ['consequ',
#   'return',
#   'check',
#   'payment',
#   'payment',
#   'coupon',
#   'receiv',
#   'along',
#   'copi',
#   'return',
#   'datestamp',
#   'envelop',
#   'explain',
#   'whi',
#   'payment',
#   'wa',
#   'arriv',
#   'late'],
#  ['also',
#   'includ',
#   'separ',
#   'check',
#   'late',
#   'fee',
#   'becaus',
#   'problem',
#   'occur',
#   'error',
#   'wa',
#   'fault',
#   'assum',
#   'fault',
#   'well',
#   'fargo',
#   'howev',
#   'wa',
#   'doubt',
#   'postal',
#   'error',
#   'due',
#   'busi',
#   'season'],
#  ['wrote',
#   'well',
#   'fargo',
#   'time',
#   'request',
#   'well',
#   'fargo',
#   'file',
#   'derogatori',
#   'rate',
#   'credit',
#   'agenc',
#   'sinc',
#   'wa',
#   'postal',
#   'error',
#   'deliber',
#   'act',
#   'either',
#   'parti'],
#  ['well',
#   'fargo',
#   'wa',
#   'cooper',
#   'us',
#   'even',
#   'though',
#   'histori',
#   'pay',
#   'late'],
#  ['well',
#   'fargo',
#   'wrote',
#   'letter',
#   'state',
#   'would',
#   'report',
#   'neg',
#   'rate',
#   'becaus',
#   'payment',
#   'receiv'],
#  ['time',
#   'letter',
#   'well',
#   'fargo',
#   'state',
#   'dont',
#   'detach',
#   'payment',
#   'coupon',
#   'statement',
#   'pleas',
#   'note',
#   'account',
#   'number',
#   'memo',
#   'section',
#   'check'],
#  ['payment',
#   'may',
#   'mail',
#   'well',
#   'fargo',
#   'home',
#   'mortgag',
#   'ca',
#   'onli',
#   'done',
#   'thisw',
#   'sent',
#   'well',
#   'fargo',
#   'copi',
#   'datestamp',
#   'envelop',
#   'prove'],
#  ['call', 'directli', 'extent', 'spoke', 'directli'],
#  ['took', 'posit', 'well', 'fargo', 'extend', 'courtesi', 'custom'],
#  ['ask',
#   'speak',
#   'supervisor',
#   'wa',
#   'transfer',
#   'support',
#   'posit',
#   'well',
#   'fargo',
#   'state',
#   'even',
#   'though',
#   'mail',
#   'payment',
#   'note',
#   'sinc',
#   'receiv',
#   'feder',
#   'regul',
#   'report',
#   'late',
#   'payment'],
#  ['ask',
#   'agenc',
#   'would',
#   'enforc',
#   'ridg',
#   'regul',
#   'state',
#   'wa',
#   'fcra',
#   'cfpb',
#   'whi',
#   'write',
#   'thi',
#   'complaint'],
#  ['becaus',
#   'neg',
#   'rate',
#   'report',
#   'credit',
#   'agenc',
#   'credit',
#   'report',
#   'took',
#   '35',
#   'dive',
#   'dure',
#   'time',
#   'prepar',
#   'retir',
#   'make',
#   'major',
#   'purchas',
#   'adjust',
#   'new',
#   'life',
#   'style'],
#  ['thi',
#   'report',
#   'ha',
#   'serious',
#   'hinder',
#   'us',
#   'senior',
#   'beyond',
#   'reprehens'],
#  ['held',
#   'thi',
#   'hardlin',
#   'tactic',
#   'abus',
#   'well',
#   'fargo',
#   'held',
#   'equal',
#   'account',
#   'fail',
#   'follow',
#   'regul',
#   'z',
#   'requir',
#   'assur',
#   'consum',
#   'accur',
#   'monthli',
#   'statement'],
#  ['loan', 'fulli', 'use'],
#  ['sent',
#   'pioneer',
#   'credit',
#   'threaten',
#   'take',
#   'everyth',
#   'sign',
#   'payment',
#   'plan'],
#  ['sign', 'pay', 'around', '50000', 'month', 'wa', 'paid'],
#  ['claim', 'still', 'owe', 'everyth', 'harrass', 'payment'],
#  ['also',
#   'ask',
#   'portion',
#   'loan',
#   'use',
#   'return',
#   'sinc',
#   'onli',
#   'use',
#   'less',
#   '1',
#   'year',
#   'worth'],
#  ['top', 'loan', 'pay', 'school', 'month'],
#  ['6', 'year', 'later', 'still', 'owe'],
#  ['also',
#   'never',
#   'receiv',
#   'anyth',
#   'wa',
#   'suppos',
#   'get',
#   'financi',
#   'aid',
#   'loan'],
#  ['sent',
#   'disput',
#   'state',
#   'author',
#   'well',
#   'polic',
#   'report',
#   'wa',
#   'told',
#   'noth',
#   'could',
#   'done',
#   'even',
#   'though',
#   'wa',
#   'fraud',
#   'wa',
#   'author',
#   'wa',
#   'also',
#   'issu',
#   'tran',
#   'union',
#   'wa',
#   'victim',
#   'inquiri',
#   'issu',
#   'sometim',
#   'dure',
#   'date',
#   'includ',
#   'top'],
#  ['also', 'well', 'polic', 'report', 'number'],
#  ['sent', 'scammer', 'money', 'never', 'deliv', 'side', 'agreement'],
#  ['tri',
#   'transact',
#   'stop',
#   'immedi',
#   'sent',
#   'money',
#   'realiz',
#   'sale',
#   'wa',
#   'scam',
#   'refus',
#   'even',
#   'open',
#   'investig',
#   'befor',
#   'fund',
#   'deliv',
#   'next',
#   'day'],
#  ['file', 'polic', 'report', 'attach', 'later', 'even'],
#  ['follow', 'day', 'contact', 'initi', 'claim'],
#  ['said',
#   'would',
#   'investig',
#   'transact',
#   'would',
#   'contact',
#   'bank',
#   'scammer',
#   'bank'],
#  ['day',
#   'later',
#   'receiv',
#   'letter',
#   'say',
#   'claim',
#   'wa',
#   'deni',
#   'wa',
#   'noth',
#   'could'],
#  ['ask',
#   'wa',
#   'ani',
#   'way',
#   'could',
#   'shut',
#   'scammer',
#   'account',
#   'said',
#   'wa'],
#  ['also', 'said', 'contact', 'retriev', 'money', 'sinc', 'wa', 'servic'],
#  ['discuss', 'anoth', 'account', 'becaus', 'im', 'custom'],
#  ['ive',
#   'tri',
#   'contact',
#   'speak',
#   'sinc',
#   'transact',
#   'wa',
#   'file',
#   'bank',
#   'said',
#   'resolv',
#   'disput',
#   'bank'],
#  ['seem', 'point', 'finger'],
#  ['bottom',
#   'line',
#   'doesnt',
#   'take',
#   'secur',
#   'serious',
#   'doesnt',
#   'care',
#   'custom',
#   'tri',
#   'stop',
#   'fraud',
#   'befor',
#   'happen'],
#  ['time', 'receiv', 'phone', 'call', 'cell', 'phone'],
#  ['autom',
#   'messag',
#   'indic',
#   'attempt',
#   'sever',
#   'time',
#   'contact',
#   'regard',
#   'credit',
#   'card',
#   'account',
#   'exhaust',
#   'option',
#   'order',
#   'reach',
#   'help',
#   'lower',
#   'credit',
#   'card',
#   'interest',
#   'rate'],
#  ['autom',
#   'messag',
#   'onli',
#   'indic',
#   'wa',
#   'wa',
#   'decept',
#   'make',
#   'believ',
#   'someth',
#   'wa',
#   'wrong',
#   'credit',
#   'card',
#   'account'],
#  ['hung', 'call', 'number', 'back', 'wa'],
#  ['attempt',
#   'bypass',
#   'autom',
#   'option',
#   'order',
#   'talk',
#   'custom',
#   'servic',
#   'repres',
#   'wa',
#   'concern',
#   'may',
#   'credit',
#   'card',
#   'open',
#   'unknown'],
#  ['could',
#   'bypass',
#   'autom',
#   'option',
#   'instead',
#   'conduct',
#   'search',
#   'determin',
#   'thi',
#   'wa',
#   'citi',
#   'credit',
#   'card',
#   'product'],
#  ['conduct',
#   'citi',
#   'directli',
#   'time',
#   'complain',
#   'unsolicit',
#   'decept',
#   'autom',
#   'messag',
#   'custom',
#   'repres'],
#  ['custom', 'repres', 'took', 'complaint', 'apolog'],
#  ['want',
#   'share',
#   'complaint',
#   'autom',
#   'messag',
#   'call',
#   'origin',
#   'wa',
#   'veri',
#   'decept',
#   'make',
#   'feel',
#   'like',
#   'account',
#   'issu',
#   'rather',
#   'market',
#   'option',
#   'lower',
#   'credit',
#   'card',
#   'rate'],
#  ['addit', 'possess', 'ever', 'issu', 'citi'],
#  ['feel',
#   'thi',
#   'wa',
#   'unsolicit',
#   'market',
#   'activ',
#   'provid',
#   'sinc',
#   'call',
#   'list'],
#  ['thank'],
#  ['call',
#   'place',
#   'transunion',
#   'regard',
#   'inaccur',
#   'inform',
#   'credit',
#   'report',
#   'call'],
#  ['spoke', 'name', 'manag', 'gave'],
#  ['state', 'account', 'show', 'balanc'],
#  ['explain', 'sent', 'letter', 'acct'],
#  ['mail',
#   'transunion',
#   'account',
#   'wa',
#   'paid',
#   'full',
#   'compani',
#   'sent',
#   'inform'],
#  ['state', 'inform', 'go', 'chang', 'leav', 'inform', 'credit', 'report'],
#  ['thought',
#   'credit',
#   'report',
#   'agenc',
#   'provid',
#   'accur',
#   'inform',
#   'oppos',
#   'fight',
#   'phone',
#   'regard',
#   'inform'],
#  ['sent',
#   'copi',
#   'wa',
#   'receiv',
#   'form',
#   'compani',
#   'wa',
#   'paid',
#   'updat',
#   'three',
#   'credit',
#   'bureau'],
#  ['tri', 'figur', 'whi', 'inform', 'updat', 'accur'],
#  ['chase',
#   'bank',
#   'ha',
#   'polici',
#   'ani',
#   'deposit',
#   'made',
#   'credit',
#   'next',
#   'day',
#   'howev',
#   'cash',
#   'deposit',
#   'show',
#   'avail',
#   'money',
#   'account',
#   'avail',
#   'make',
#   'deposit',
#   'anytim',
#   'day',
#   'night'],
#  ['chase',
#   'openli',
#   'admit',
#   'charg',
#   'account',
#   'three',
#   'time',
#   'becaus',
#   'cash',
#   'deposit',
#   'wa',
#   'made',
#   'transact',
#   'push',
#   'night',
#   'caus',
#   'overdraft',
#   'fee',
#   'despit',
#   'fact',
#   'account',
#   'clearli',
#   'show',
#   'avail',
#   'balanc',
#   'higher',
#   'transact'],
#  ['chase', 'hide', 'behind', 'polici', 'crimin'],
#  ['cash',
#   'deposit',
#   'wa',
#   'account',
#   'befor',
#   'charg',
#   'push',
#   'avail',
#   'balanc',
#   'wa',
#   'higher',
#   'charg',
#   'chase',
#   'still',
#   'charg',
#   'overdraft',
#   'fee'],
#  ['notic',
#   'chase',
#   'bank',
#   'complaint',
#   'messag',
#   'board',
#   'numer',
#   'similar',
#   'complaint',
#   'someon',
#   'point',
#   'obviou',
#   'fact',
#   'cash',
#   'deposit',
#   'cash',
#   'deposit'],
#  ['doe', 'matter', 'time', 'deposit'],
#  ['given',
#   'automat',
#   'avail',
#   'balanc',
#   'money',
#   'bank',
#   'befor',
#   'charg',
#   'go',
#   'avail',
#   'would',
#   'illeg',
#   'say',
#   'insuffici',
#   'fund'],
#  ['tri',
#   'thi',
#   'debt',
#   'valid',
#   'last',
#   'sent',
#   'valid',
#   'letter',
#   'credit',
#   'agenc',
#   '2016',
#   'yet',
#   'receiv',
#   'ani',
#   'valid',
#   'document',
#   'delet',
#   'inform'],
#  ['2017',
#   'eastern',
#   'time',
#   'citizen',
#   'unit',
#   'state',
#   'tri',
#   'obtain',
#   'credit',
#   'card',
#   'discov'],
#  ['reason',
#   'find',
#   'obnoxi',
#   'seem',
#   'declin',
#   'credit',
#   'bureau',
#   'inquiri',
#   'find',
#   'highli',
#   'untru',
#   'due',
#   'nt',
#   'request',
#   'card',
#   'sinc',
#   'turn',
#   'legal',
#   'age'],
#  ['anoth',
#   'issu',
#   'speak',
#   'agent',
#   'live',
#   'chat',
#   'specif',
#   'agent',
#   'claim',
#   'approv',
#   'provid',
#   'document',
#   'need',
#   'told',
#   'agent',
#   'want',
#   'card',
#   'email',
#   'workplac',
#   'ask',
#   'document',
#   'tri',
#   'follow',
#   'seem',
#   'live',
#   'chat',
#   'end'],
#  ['ask',
#   'anoth',
#   'agent',
#   'agent',
#   'wa',
#   'veri',
#   'unhelp',
#   'give',
#   'reason',
#   'whi',
#   'one',
#   'declin',
#   'approv',
#   'well',
#   'whi',
#   'submit',
#   'person',
#   'document'],
#  ['feel', 'thi', 'ha', 'freud', 'behav', 'discov'],
#  ['payment', 'current'],
#  ['receiv', 'escrow', 'account', 'inform', 'sinc'],
#  ['today'],
#  ['payment', 'also', 'fraudul', 'inflat', 'period'],
#  ['mortgag',
#   'account',
#   'transfer',
#   'nationstar',
#   'properti',
#   'servic',
#   'texa'],
#  ['nationstar',
#   'continu',
#   'cash',
#   'check',
#   'without',
#   'send',
#   'ani',
#   'account',
#   'payment'],
#  ['reach', 'investor', 'still', 'result'],
#  ['feder', 'harp', 'loan', 'modif'],
#  ['submit',
#   'sever',
#   'certifi',
#   'letter',
#   'credit',
#   'bureau',
#   'inquiri',
#   'wa',
#   'unawar',
#   'list',
#   'credit',
#   'report',
#   'today',
#   'still',
#   'nt',
#   'gotten',
#   'respons'],
#  ['thi', 'situat', 'affect', 'process', 'purchas', 'home'],
#  ['pleas', 'instruct', 'next'],
#  ['look', 'forward', 'hear', 'soon'],
#  ['lost', 'job', 'begin', 'thi', 'month'],
#  ['bill', 'conn', 'wa', 'due'],
#  ['nt', 'money'],
#  ['receiv', 'phone', 'call', 'thi', 'week'],
#  ['today'],
#  ['spoken', 'differ', 'peopl', 'total'],
#  ['made',
#   'awar',
#   'last',
#   'week',
#   'could',
#   'pay',
#   'make',
#   'payment',
#   'arrang',
#   'guarante',
#   'incom',
#   'thi',
#   'time'],
#  ['today', 'wa', 'inform', 'continu', 'call', 'pay'],
#  ['limit', 'mani', 'time', 'day', 'call'],
#  ['thi', 'pure', 'harass'],
#  ['thi',
#   'make',
#   'alreadi',
#   'stress',
#   'situat',
#   'wors',
#   'keep',
#   'phone',
#   'tie',
#   'tri',
#   'look',
#   'work'],
#  ['believ',
#   'victim',
#   'ident',
#   'theft',
#   'wa',
#   'tri',
#   'improv',
#   'credit',
#   'score'],
#  ['everytim',
#   'tri',
#   'view',
#   'score',
#   'though',
#   'annualcreditscorecom',
#   'tell',
#   'data',
#   'unavail',
#   'someth',
#   'crazi',
#   'even',
#   'though',
#   'know',
#   'give',
#   'right',
#   'social',
#   'secur',
#   'number'],
#  ['also', 'prevent', 'get', 'past'],
#  ['disput',
#   'account',
#   'equifax',
#   'concern',
#   'author',
#   'user',
#   'account',
#   'wa',
#   'delet',
#   'equifax',
#   'continu',
#   'report',
#   'contact',
#   'phone',
#   'us',
#   'mail'],
#  ['check',
#   'credit',
#   'report',
#   'notic',
#   'charg',
#   'note',
#   'everi',
#   'singl',
#   'month',
#   'includ',
#   '2015'],
#  ['insert', 'befor', 'disput'],
#  ['weird',
#   'thing',
#   'author',
#   'user',
#   'account',
#   'equifax',
#   'seem',
#   'verifi',
#   'doe',
#   'match',
#   'report',
#   'account',
#   'holder'],
#  ['author',
#   'user',
#   'account',
#   'report',
#   'much',
#   'neg',
#   'believ',
#   'equifax',
#   'thi',
#   'spite',
#   'becaus',
#   'disput',
#   'account'],
#  ['author', 'user', 'thi', 'account'],
#  ['equifax',
#   'need',
#   'rememb',
#   'author',
#   'user',
#   'account',
#   'respons',
#   'account',
#   'ca',
#   'nt',
#   'order',
#   'new',
#   'card',
#   'request',
#   'statement',
#   'etc'],
#  ['equifax',
#   'violat',
#   'fals',
#   'verifi',
#   'thi',
#   'account',
#   'continu',
#   'report'],
#  ['verifi',
#   'would',
#   'nt',
#   'abl',
#   'sinc',
#   'complet',
#   'delet',
#   'author',
#   'user',
#   'year',
#   'yet',
#   'equifax',
#   'continu',
#   'updat',
#   'add',
#   'neg',
#   'inform',
#   'time',
#   'disput'],
#  ['file',
#   'thi',
#   'complaint',
#   'becaus',
#   'experian',
#   'ha',
#   'refus',
#   'provid',
#   'document',
#   'compani',
#   'ha',
#   'file',
#   'use',
#   'verifi',
#   'account',
#   'disput'],
#  ['gone',
#   'past',
#   '30',
#   'day',
#   'mark',
#   'verifi',
#   'account',
#   'section',
#   '611',
#   '5',
#   'fcra',
#   'requir',
#   'promptli',
#   'delet',
#   'inform',
#   'verifi',
#   'disput'],
#  ['pleas', 'resolv', 'thi', 'matter', 'soon', 'possibl'],
#  ['thank'],
#  ['open', 'new', 'card', 'amex'],
#  ['account',
#   'wa',
#   'open',
#   'less',
#   'month',
#   'amex',
#   'request',
#   'see',
#   'prior',
#   'tax',
#   'return',
#   'past',
#   'two',
#   'year'],
#  ['specif', 'told', 'amex', 'file', 'tax', 'yet', 'request', 'extens'],
#  ['told', 'need', 'file', 'tax', '15', 'day'],
#  ['file',
#   'tax',
#   'order',
#   'keep',
#   'account',
#   'open',
#   'fill',
#   'request',
#   'inform'],
#  ['15',
#   'day',
#   'call',
#   'amex',
#   'told',
#   'file',
#   'tax',
#   'close',
#   'account',
#   'exactli',
#   'told'],
#  ['also', 'amex', 'ha', 'lie', 'payment', 'wa', 'due'],
#  ['offer', 'amex', 'see', 'return', 'reject', 'request'],
#  ['call',
#   'multipl',
#   'time',
#   'get',
#   'thi',
#   'issu',
#   'resolv',
#   'amex',
#   'ha',
#   'done',
#   'anyth',
#   'help',
#   'far',
#   'keep',
#   'account',
#   'open'],
#  ['loan', 'went', 'forbear', 'without', 'consent'],
#  ['file', 'complaint', 'art', 'institut', 'naviant'],
#  ['complaint', 'wa', 'process', 'must', 'put', 'loan', 'forbear'],
#  ['wa', 'autopay', 'stop'],
#  ['call',
#   'naviant',
#   'nt',
#   '1',
#   'hour',
#   'wait',
#   'phone',
#   'onli',
#   'get',
#   'callback'],
#  ['email'],
#  ['pnaviant',
#   'wa',
#   'call',
#   'phone',
#   '8',
#   'time',
#   'day',
#   'befor',
#   'thi',
#   'even',
#   'though',
#   'wa',
#   'autopay'],
#  ['sure', 'handl', 'thi'],
#  ['interest', 'rate', 'high', 'touch', 'principl'],
#  ['citibank',
#   'credit',
#   'card',
#   'sent',
#   'collect',
#   'report',
#   'neg',
#   'credit',
#   'file',
#   'continu',
#   'collect',
#   'charg',
#   'disput',
#   'year'],
#  ['wrong',
#   'amount',
#   'charg',
#   'disput',
#   'soon',
#   'notic',
#   'comaoni',
#   'mani',
#   'time',
#   'via',
#   'email',
#   'usp',
#   'mail',
#   'phone'],
#  ['compani',
#   'ha',
#   'refus',
#   'correct',
#   'error',
#   'remov',
#   'balanc',
#   'charg',
#   'continu',
#   'add',
#   'fee',
#   'report',
#   'neg'],
#  ['thi', 'account', 'balanc', 'belong'],
#  ['alreadi', 'know', 'sc', 'say'],
#  ['check',
#   'question',
#   'wa',
#   'bill',
#   'pay',
#   'account',
#   'fund',
#   'check',
#   'befor',
#   'sent'],
#  ['pleas', 'see', 'note'],
#  ['bank', 'confirm', 'thi', 'wa', 'sent', '2016'],
#  ['deposit', '113', 'day', 'later'],
#  ['pay', 'outstand', 'loan', 'son'],
#  ['send', 'check', 'bank', 'bill', 'pay', 'system'],
#  ['check',
#   'state',
#   'check',
#   'void',
#   '90',
#   'day',
#   'secur',
#   'credit',
#   'system',
#   'purpos',
#   'held',
#   'check',
#   '113',
#   'day',
#   'befor',
#   'deposit'],
#  ['check', 'deliv', '2016', 'place', 'deposit', '2016'],
#  ['accus', 'bounc', 'check', 'longer', 'accept', 'check', 'payment'],
#  ['return', 'check'],
#  ['request', 'money', 'order', 'onli'],
#  ['send', 'check', 'directli', 'school'],
#  ['accus',
#   'write',
#   'bad',
#   'check',
#   'plan',
#   'research',
#   'take',
#   'court',
#   'defam',
#   'charact'],
#  ['1the', 'check', 'wa', 'return', 'nsf'],
#  ['wa', 'void', 'due', 'failur', 'deposit'],
#  ['check', 'void', '90', 'day', '2'],
#  ['send', 'anyon', 'money', 'order'],
#  ['3'],
#  ['continu', 'send', 'check', 'directli', 'figur', 'send', 'check'],
#  ['4'],
#  ['check', 'wa', 'return', 'nsf'],
#  ['go', 'legal', 'action', 'thi', 'claim', 'correct'],
#  ['thank'],
#  ['made', 'withdraw', 'prosper', 'bank', 'littl', 'dollar', 'believ'],
#  ['withdraw', 'receiv', 'account', 'balanc', 'lower', 'balanc'],
#  ['wa', 'ok'],
#  ['wa', 'expect', 'anoth', 'direct', 'deposit', 'day', 'second', 'employ'],
#  ['sunday', 'balanc', 'reflect', 'littl', 'dollar'],
#  ['went', 'ahead', 'transact'],
#  ['mid', 'monday', 'account', 'wa', 'neg'],
#  ['wa', 'confus', 'frustrat'],
#  ['paid',
#   'much',
#   'money',
#   'fee',
#   'especi',
#   'overdraft',
#   'fee',
#   'prosper',
#   'bank'],
#  ['banker', 'help', 'never', 'answer', 'question'],
#  ['alway', 'issu', 'log', 'onlin', 'view', 'account', 'better', 'manag'],
#  ['alway', 'call', 'custom', 'servic', 'success', 'result'],
#  ['keep', 'pay', 'fee', 'could', 'avoid', 'onli', 'get', 'help'],
#  ['frustrat', 'think', 'thi', 'bank', 'trustworthi'],
#  ['thi', 'whi', 'cfpb', 'wa', 'creat', 'bank', 'like', 'thi'],
#  ['nt', 'open', 'account', 'prosper', 'bank'],
#  ['thi', 'junk', 'cray'],
#  ['cant', 'stand', 'call', 'time', 'account', 'aint', 'mine'],
#  ['sent',
#   'ceas',
#   'desist',
#   'thinkin',
#   'would',
#   'help',
#   'didnt',
#   'soo',
#   'sent',
#   'anoth'],
#  ['aint', 'workin'],
#  ['open',
#   'privat',
#   'student',
#   'loan',
#   'well',
#   'fargo',
#   'bank',
#   'amount',
#   '750000'],
#  ['father',
#   'paid',
#   '750000',
#   'howev',
#   'month',
#   'receiv',
#   'bill',
#   '590000',
#   'interest',
#   'charg',
#   'loan',
#   'wa',
#   'alreadi',
#   'paid'],
#  ['wa', 'still', 'grace', 'period', 'ani', 'interest', 'run', 'loan'],
#  ['contact',
#   'well',
#   'fargo',
#   'costum',
#   'servic',
#   'thi',
#   'student',
#   'loan',
#   'person',
#   'phone',
#   'sever',
#   'time',
#   'result',
#   'thi',
#   'interest',
#   'charg'],
#  ['thi',
#   'moment',
#   'father',
#   'ha',
#   'pay',
#   'interest',
#   'monthli',
#   'includ',
#   'interest',
#   'balanc',
#   'plu',
#   'interest'],
#  ['leas'],
#  ['leas',
#   'matur',
#   'befor',
#   'matur',
#   'date',
#   'contact',
#   'lexu',
#   'financi',
#   'servic',
#   'ask',
#   '6',
#   'month',
#   'extens'],
#  ['rep',
#   'took',
#   'request',
#   'told',
#   'notifi',
#   'shortli',
#   'weather',
#   'extens',
#   'wa',
#   'grant'],
#  ['call',
#   'day',
#   'later',
#   'custom',
#   'servic',
#   'told',
#   'could',
#   'see',
#   'saw',
#   'payment',
#   'next',
#   'month',
#   'wa',
#   'avail',
#   'meant',
#   'extens',
#   'wa',
#   'grant'],
#  ['log', 'lf', 'account', 'payment', 'month', 'wa', 'due'],
#  ['made', 'payment', 'wa', 'impress', 'leas', 'extens', 'wa', 'grant'],
#  ['next', 'payment', 'notif', 'came', 'paid', 'well'],
#  ['day',
#   'payment',
#   'morn',
#   'tow',
#   'truck',
#   'two',
#   'beast',
#   'get',
#   'insid',
#   'properti',
#   'tow',
#   'away',
#   'car'],
#  ['get', 'confus', 'think', 'theft'],
#  ['tri',
#   'get',
#   'stuff',
#   'car',
#   'make',
#   'sure',
#   'wa',
#   'theft',
#   'one',
#   'beast',
#   'block',
#   'took'],
#  ['call', 'polic', 'depart', 'wa', 'advis', 'could', 'financi', 'servic'],
#  ['got', 'doubt', 'becaus', 'knew', 'made', 'payment'],
#  ['call', 'lf', 'apolog', 'told', 'extens', 'wa', 'never', 'grant'],
#  ['call',
#   'anoth',
#   'time',
#   'pose',
#   'question',
#   'weather',
#   'made',
#   'mistak',
#   'realli',
#   'act',
#   'complianc',
#   'california',
#   'law'],
#  ['ask',
#   'leas',
#   'past',
#   'matur',
#   'date',
#   'extens',
#   'grant',
#   'suppos',
#   'accept',
#   'payment',
#   'answer',
#   'wa'],
#  ['month',
#   'incid',
#   'sent',
#   'letter',
#   'thank',
#   'return',
#   'vehicl',
#   'vehicl',
#   'excess',
#   'mileageand',
#   'wear',
#   'defin',
#   'leas',
#   'agreement',
#   'unpaid',
#   'charg'],
#  ['statement', 'read', 'owe', '240000'],
#  ['call',
#   'told',
#   'vehicl',
#   'excess',
#   'mileag',
#   'excess',
#   'mile',
#   'paid',
#   'two',
#   'extra',
#   'payment',
#   'made',
#   'matur',
#   'date'],
#  ['answer', 'insist', 'amount', 'wa', 'due', 'need', 'paid'],
#  ['good',
#   'afternoon',
#   'make',
#   'disput',
#   'make',
#   'hard',
#   'inquiri',
#   'credit',
#   'report'],
#  ['believ',
#   'wa',
#   'sent',
#   'preapprov',
#   'offer',
#   'letter',
#   'mail',
#   'wa',
#   'told',
#   'ani',
#   'preapprov',
#   'offer',
#   'report',
#   'soft',
#   'inquiri'],
#  ['howev', 'wa', 'noth', 'soft', 'thi', 'inquiri'],
#  ['thi',
#   'hard',
#   'inquiri',
#   'along',
#   'ha',
#   'fact',
#   'ravag',
#   'credit',
#   'score',
#   'caus',
#   'credit',
#   'score',
#   'plummet',
#   'excel',
#   'score'],
#  ['wa',
#   'consid',
#   'get',
#   'mortgag',
#   'loan',
#   'month',
#   'hard',
#   'inquiri',
#   'look',
#   'good',
#   'bank',
#   'lender'],
#  ['modifac',
#   'well',
#   'fargo',
#   'mortgag',
#   'want',
#   '250000',
#   'month',
#   'least',
#   '6',
#   'month',
#   'get',
#   'caught',
#   'payment',
#   'said',
#   'wa',
#   'way',
#   'much',
#   'offer',
#   '160000',
#   'nt',
#   'respond',
#   'plan',
#   'foreclos',
#   'thi',
#   'month',
#   'nt',
#   'pay',
#   '250000',
#   'contact',
#   'mani',
#   'gov',
#   'websit',
#   'said',
#   'contact'],
#  ['thank', 'ph'],
#  [],
#  ['yearold',
#   'mother',
#   'incur',
#   '2900',
#   'charg',
#   'searsciticorp',
#   'credit',
#   'card',
#   'payment',
#   'due',
#   '2016'],
# ...
#  ['refus', 'deliveri', 'sofa', 'wa', 'sent', 'back', 'warehous'],
#  ['next',
#   'day',
#   'contact',
#   'phone',
#   'sent',
#   'email',
#   'reason',
#   'refus',
#   'deliveri',
#   'pictur',
#   'support',
#   'claim'],
#  ['also', 'initi', 'disput', 'payment', 'chase', 'freedom'],
#  ['receiv',
#   'email',
#   'advis',
#   'inspect',
#   'wa',
#   'complet',
#   'sofa',
#   'oper',
#   'normal'],
#  ['none',
#   'item',
#   'document',
#   'letter',
#   'pictur',
#   'address',
#   'thi',
#   'email',
#   'except',
#   'assert',
#   'arm',
#   'loos'],
#  ['disagre'],
#  ['note', 'inspect', 'wa', 'perform', 'senior', 'technician'],
#  ['believ',
#   'vest',
#   'interest',
#   'ensur',
#   'sofa',
#   'pass',
#   'inspect',
#   'would',
#   'held',
#   'respons',
#   'damag',
#   'sofa',
#   'shipment'],
#  ['also',
#   'believ',
#   'damag',
#   'occur',
#   'dure',
#   'ship',
#   'wa',
#   'forc',
#   'doorway',
#   'caus',
#   '48000',
#   'damag',
#   'doorfram'],
#  ['given',
#   'two',
#   'option',
#   '1',
#   'redeliveri',
#   'sofa',
#   '2',
#   'pay',
#   '50',
#   'restock',
#   'fee',
#   'damag',
#   'sofa',
#   'refus',
#   'deliveri'],
#  ['want',
#   'redeliveri',
#   'sofa',
#   'would',
#   'still',
#   'damag',
#   'damag',
#   'would',
#   'occur',
#   'sofa',
#   'doorfram',
#   'forc',
#   'sofa',
#   'door'],
#  ['also',
#   'state',
#   'could',
#   'order',
#   'anoth',
#   'sofa',
#   'desir',
#   'repeat',
#   'experi',
#   'thi',
#   'merchant'],
#  ['letter', 'chase', 'date', 'receiv', 'advis', 'chase', 'provid', 'respons'],
#  ['compil',
#   'detail',
#   'respons',
#   'includ',
#   'pictur',
#   'support',
#   'claim',
#   'sent',
#   'via',
#   'usp',
#   'prioriti',
#   'mail'],
#  ['sent', 'chase', 'secur', 'messag', 'via', 'site', 'advis', 'action'],
#  ['accord',
#   'us',
#   'postal',
#   'servic',
#   'respons',
#   'wa',
#   'receiv',
#   'day',
#   'befor',
#   'deadlin',
#   'check',
#   'balanc',
#   'card',
#   'discov',
#   'disput',
#   'amount',
#   'total',
#   '560000',
#   'charg',
#   'back',
#   'account'],
#  ['call',
#   'chase',
#   'advis',
#   'made',
#   'decis',
#   'befor',
#   'paperwork',
#   'arriv',
#   'correct',
#   'depart'],
#  ['reason',
#   'given',
#   'deni',
#   'disput',
#   'didnt',
#   'return',
#   'merchandis',
#   'make',
#   'arrang',
#   'merchant',
#   'pick'],
#  ['thi', 'total', 'untru', 'refus', 'deliveri', 'sofa'],
#  ['correspond', 'vendor', 'clearli', 'state', 'thi'],
#  ['also',
#   'advis',
#   'merchant',
#   'state',
#   'like',
#   'sofa',
#   'wa',
#   'reason',
#   'return'],
#  ['also', 'total', 'untru', 'refus', 'shipment', 'becaus', 'damag'],
#  ['verifi',
#   'chase',
#   'receiv',
#   'respons',
#   'advis',
#   'could',
#   'reopen',
#   'disput'],
#  ['also',
#   'sent',
#   'secur',
#   'messag',
#   'via',
#   'chase',
#   'websit',
#   'express',
#   'concern',
#   'one',
#   'wa',
#   'look',
#   'inform',
#   'specif',
#   'case',
#   'make',
#   'determin'],
#  ['ask', 'chase', 'use', 'avail', 'inform', 'resolv', 'disput'],
#  ['receiv', 'correspond', 'chase', 'date', 'deni', 'disput'],
#  ['reason',
#   'cite',
#   'merchant',
#   'credit',
#   'account',
#   'isnt',
#   'requir',
#   'becaus',
#   'charg',
#   'took',
#   'place',
#   'long',
#   'ago'],
#  ['immedi',
#   'call',
#   'chase',
#   'discuss',
#   'thi',
#   'told',
#   'supervisor',
#   'everyth',
#   'correctli',
#   'time',
#   'manner',
#   'wa',
#   'noth',
#   'could',
#   'becaus',
#   'ran',
#   'time'],
#  ['didnt', 'run', 'time', 'chase'],
#  ['provid',
#   'bogu',
#   'reason',
#   'deni',
#   'disput',
#   'cite',
#   'didnt',
#   'return',
#   'merchandis',
#   'untru'],
#  ['reopen',
#   'disput',
#   'becaus',
#   'chase',
#   'error',
#   'even',
#   'time',
#   'pass',
#   'shorten',
#   'time',
#   'avail',
#   'review',
#   'case'],
#  ['lack',
#   'urgenc',
#   'failur',
#   'review',
#   'case',
#   'within',
#   'time',
#   'limit',
#   'must',
#   'born',
#   'chase'],
#  ['instead',
#   'wa',
#   'easier',
#   'chase',
#   'blame',
#   'time',
#   'limit',
#   'rather',
#   'take',
#   'respons',
#   'failur',
#   'act',
#   'fair',
#   'time',
#   'manner'],
#  ['first',
#   'decis',
#   'base',
#   'untruth',
#   'return',
#   'sofa',
#   'second',
#   'decis',
#   'base',
#   'merchant',
#   'requir',
#   'credit',
#   'account',
#   'becaus',
#   'time',
#   'limit',
#   'indic',
#   'fact',
#   'case',
#   'outlin',
#   'detail',
#   'respons',
#   'never',
#   'review',
#   'chase',
#   'consid',
#   'issu',
#   'disput',
#   'denial'],
#  ['case', 'deserv'],
#  ['intent',
#   'use',
#   'chase',
#   'credit',
#   'card',
#   'protect',
#   'ourselv',
#   'situat',
#   'like',
#   'thi'],
#  ['chase',
#   'provid',
#   'protect',
#   'even',
#   'thoroughli',
#   'review',
#   'case',
#   'basic',
#   'rubberstamp',
#   'decis'],
#  ['reason',
#   'first',
#   'denial',
#   'wa',
#   'didnt',
#   'return',
#   'merchandis',
#   'obviou',
#   'chase',
#   'even',
#   'read',
#   'paperwork'],
#  ['second', 'denial', 'wa', 'base', 'merchant', 'unwil', 'credit', 'account'],
#  ['leather',
#   'shopp',
#   'untruth',
#   'state',
#   'didnt',
#   'like',
#   'sofa',
#   'assert',
#   'sofa',
#   'wa',
#   'damag',
#   'even',
#   'though',
#   'provid',
#   'pictur',
#   'show',
#   'otherwis'],
#  ['chase',
#   'decis',
#   'base',
#   'untruth',
#   'word',
#   'technician',
#   'contract',
#   'merchant'],
#  ['chase',
#   'chose',
#   'believ',
#   'vest',
#   'interest',
#   'protect',
#   'rather',
#   'evid',
#   'provid',
#   'custom',
#   'suppos',
#   'protect'],
#  ['addit',
#   'chase',
#   'said',
#   'charg',
#   'old',
#   'even',
#   'though',
#   'everyth',
#   'time',
#   'manner'],
#  ['wa',
#   'ani',
#   'delay',
#   'wa',
#   'chase',
#   'respond',
#   'us',
#   'promptli',
#   'reopen',
#   'disput'],
#  ['chase', 'use', 'inform', 'avail', 'time', 'limit', 'may', 'issu'],
#  ['never', 'advis', 'ani', 'time', 'limit', 'except', 'respons'],
#  ['thi', 'case', 'ha', 'mishandl', 'chase', 'first', 'denial'],
#  ['respons', 'pay', 'ani', 'amount', 'damag', 'good'],
#  ['chase', 'protect', 'us'],
#  ['coinbas',
#   'amount',
#   '40000',
#   'date',
#   'issu',
#   'sold',
#   'litecoin',
#   'amount',
#   '40000',
#   'transfer',
#   'fund',
#   'directli',
#   'bank',
#   'account',
#   'link',
#   'directli',
#   'coinbas',
#   'account',
#   'verifi',
#   'id'],
#  ['main',
#   'dashboard',
#   'recent',
#   'activ',
#   'withdraw',
#   'mark',
#   'complet',
#   'money',
#   'would',
#   'avail',
#   '7',
#   'day',
#   'later'],
#  ['receiv',
#   'email',
#   'day',
#   'befor',
#   'money',
#   'would',
#   'avail',
#   'state',
#   'bank',
#   'cancel',
#   'order'],
#  ['new',
#   'item',
#   'recent',
#   'histori',
#   'state',
#   'receiv',
#   'amount',
#   'litecoin',
#   'sold',
#   'note',
#   'say',
#   'sold',
#   'ltc',
#   '40000',
#   'usd'],
#  ['payment', 'sent', 'interest', 'check', 'tuesday'],
#  ['call', 'bank', 'told', 'stop', 'anyth', 'wa', 'transact', 'cancel'],
#  ['call',
#   'coinbas',
#   'support',
#   'solut',
#   'wa',
#   'file',
#   'thi',
#   'support',
#   'ticket'],
#  ['file', 'veri', 'descript', 'support', 'ticket', 'submit'],
#  ['receiv',
#   'email',
#   'coinbas',
#   'nearli',
#   '2',
#   'week',
#   'later',
#   'tell',
#   'issu',
#   'wa',
#   'list',
#   'top',
#   'prioriti',
#   'respond',
#   'describ',
#   'problem',
#   'alreadi',
#   'thoroughli',
#   'describ',
#   '2',
#   'commun'],
#  ['ha',
#   'week',
#   'sinc',
#   'commun',
#   'noth',
#   'back',
#   'coinbas',
#   'mean',
#   'lost',
#   'money',
#   'mistak',
#   'compani',
#   'guarante',
#   'would',
#   'money',
#   'specif',
#   'date'],
#  ['thi',
#   'compani',
#   'ha',
#   'financi',
#   'inform',
#   'thousand',
#   'us',
#   'citizen',
#   'trust',
#   'enough',
#   'know',
#   'whether',
#   'scam',
#   'user'],
#  ['car',
#   'wa',
#   'use',
#   'purchas',
#   'day',
#   'got',
#   'car',
#   'took',
#   'insur',
#   'agenc',
#   'add',
#   'insur',
#   'car',
#   'wouldnt',
#   'crank',
#   'back'],
#  ['end',
#   'call',
#   'explain',
#   'purchas',
#   'car',
#   'day',
#   'want',
#   'crank',
#   'dealership',
#   'said',
#   'cant',
#   'help',
#   'arent',
#   'go',
#   'get',
#   'car',
#   'fix',
#   'call',
#   'lemon',
#   'car',
#   'long',
#   'stori',
#   'short',
#   'got',
#   'phone',
#   'said',
#   'get',
#   'car',
#   'within',
#   '24',
#   'hour',
#   'came',
#   'got',
#   'car',
#   'fix',
#   'enough',
#   'get',
#   'back',
#   'home',
#   'drive',
#   'bout',
#   'anoth',
#   'month',
#   'time',
#   'told',
#   'come',
#   'get',
#   'refus',
#   'eventu',
#   'came',
#   'pick',
#   'car',
#   'put',
#   'credit',
#   'two',
#   'time',
#   'still',
#   'call',
#   'keep',
#   'tell',
#   'sold',
#   'lemon',
#   'car',
#   'regist',
#   'call',
#   'still',
#   'call',
#   'month',
#   'long',
#   'everi',
#   'month'],
#  ['complaint', 'walmart', 'check', 'walmart', 'accounti', 'mail', 'payment'],
#  ['wa', 'cash', 'bank'],
#  ['fax', 'copi', 'cash', 'check', 'front', 'back'],
#  ['fund', 'still', 'appli', 'walmart', 'account'],
#  ['expect',
#   'fund',
#   'correctli',
#   'appli',
#   'account',
#   'late',
#   'fee',
#   'interest',
#   'assess',
#   'account',
#   'credit',
#   'thi',
#   'done',
#   'immedi'],
#  ['work', 'bank'],
#  ['copi',
#   'front',
#   'back',
#   'cash',
#   'check',
#   'credit',
#   'fund',
#   'custom',
#   'within',
#   '12',
#   'busi',
#   'day'],
#  ['timefram', 'given', 'call', 'thi', 'wa', '30', 'day'],
#  ['utterli', 'unaccept', 'money'],
#  ['wa', 'research'],
#  ['work', 'find', 'check', 'wa', 'cash', 'get', 'copi', 'befor', 'contact'],
#  ['age', 'husband', 'wa', 'laid', 'hi', 'compani'],
#  ['continu', 'work', 'make', 'end', 'meet'],
#  ['age', 'wa', 'diagnos'],
#  ['wa', 'unabl', 'work'],
#  ['repeatedli', 'call', 'ask', 'could', 'lower', 'payment'],
#  ['navient', 'said', 'could', 'forbear'],
#  ['time', 'loan', 'wa', 'approxim', '4500000'],
#  ['everytim', 'forbear', 'wa', 'ask', 'lower', 'payment'],
#  ['said', 'onli', 'forbear'],
#  ['one',
#   'point',
#   'tri',
#   'pay',
#   'interest',
#   'onli',
#   'could',
#   'medic',
#   'bill',
#   'prescript',
#   'cost',
#   'etc'],
#  ['age', 'call', 'told', 'onli', 'option', 'avail', 'wa', 'forbear'],
#  ['meanwhil', '10', 'interest', 'loan', 'well', '7000000'],
#  ['way', 'ever', 'pay', 'amount'],
#  ['receiv', 'call', 'multipl', 'compani', 'help', 'us', 'pay', 'loan'],
#  ['read', 'scam'],
#  ['ca', 'nt', 'sleep', 'night', 'becaus', 'know', 'way', 'ever', 'pay'],
#  ['nt', 'read', 'take', 'everyth'],
#  ['nt', 'much', 'work', 'hard', 'younger', 'would', 'like', 'keep'],
#  ['wa', 'never', 'notifi', 'navient', 'would', 'loan', 'servic', 'happen'],
#  ['extrem', 'upset', 'wonder', 'next'],
#  ['sent',
#   'capit',
#   'one',
#   'auto',
#   'financ',
#   'letter',
#   'certifi',
#   'mail',
#   '15',
#   'ask',
#   'specif',
#   'inform',
#   'regard',
#   'account',
#   'said'],
#  ['thi',
#   'time',
#   'yet',
#   'get',
#   'document',
#   'ask',
#   'origin',
#   'creditor',
#   'provid'],
#  ['still',
#   'list',
#   'thi',
#   'account',
#   'credit',
#   'report',
#   'mark',
#   'thi',
#   'account',
#   'mark',
#   'consum',
#   'disput',
#   'account'],
#  ['wa',
#   'abl',
#   'confirm',
#   'receiv',
#   'certifi',
#   'mail',
#   'confirm',
#   'well',
#   'respond',
#   'nt',
#   'understand',
#   'request'],
#  ['request',
#   'wa',
#   'veri',
#   'clear',
#   'concis',
#   'thi',
#   'point',
#   'nt',
#   'receiv',
#   'document',
#   'ask',
#   'still',
#   'report',
#   'credit',
#   'report'],
#  ['includ', 'letter'],
#  ['direct', 'violat', 'fcra', 'fair', 'credit', 'report', 'act'],
#  ['credit',
#   'account',
#   'synchroni',
#   'financi',
#   'amazon',
#   'store',
#   'card',
#   'banana',
#   'republ',
#   'visa'],
#  ['address',
#   'list',
#   'account',
#   'ha',
#   'inexplic',
#   'chang',
#   'incorrect',
#   'address',
#   'unabl',
#   'correctupd',
#   'via',
#   'websit',
#   'custom',
#   'servic'],
#  ['wa', 'told', 'custom', 'servic', 'correct', 'chang', 'ever', 'appear'],
#  ['address',
#   'list',
#   'amazon',
#   'store',
#   'card',
#   'address',
#   'ha',
#   'never',
#   'address',
#   'wa',
#   'never',
#   'provid'],
#  ['address',
#   'list',
#   'banana',
#   'republ',
#   'visa',
#   'undeliver',
#   'onli',
#   'apart',
#   'number',
#   'street',
#   'address',
#   'incorrect',
#   'zip',
#   'code'],
#  ['asid',
#   'unabl',
#   'receiv',
#   'paper',
#   'statement',
#   'see',
#   'synchroni',
#   'ha',
#   'report',
#   'least',
#   'one',
#   'bogu',
#   'address',
#   'credit',
#   'report',
#   'entiti'],
#  ['request',
#   'credit',
#   'report',
#   'ident',
#   'theft',
#   'said',
#   'could',
#   'prove',
#   'ident',
#   'address',
#   'iam',
#   'current',
#   'move',
#   'va',
#   'use',
#   'live',
#   'va',
#   '1y12',
#   'year'],
#  ['ive', 'servic', 'loan', 'almst', '18', 'yr'],
#  ['unknown',
#   'without',
#   'notic',
#   'took',
#   'rais',
#   'payment',
#   'chang',
#   'amount',
#   'owe'],
#  ['navient', 'servic'],
#  ['ive',
#   'unsuccess',
#   'get',
#   'incom',
#   'base',
#   'repay',
#   'plan',
#   'like',
#   'one',
#   'last',
#   '3',
#   'year'],
#  ['ive', 'fax', 'document', 'approx', '67', 'time', 'period'],
#  ['issu', 'forebear', 'keep', 'rais', 'payment', 'amount', 'loan', 'amount'],
#  ['loan'],
#  ['loan',
#   'consolid',
#   'without',
#   'give',
#   'notic',
#   'clock',
#   'would',
#   'complet',
#   'reset',
#   'payment',
#   'period'],
#  ['need',
#   'assist',
#   'asap',
#   'get',
#   'incom',
#   'base',
#   'repay',
#   'plan',
#   'clock',
#   'reset',
#   '12',
#   'year',
#   'good',
#   'stand'],
#  ['didnt', 'author', 'navient', 'servic', 'loan', 'want', 'loan', 'servic'],
#  ['get', 'nonstop', 'call', 'email', 'everi', '3', 'month', 'forbear'],
#  ['explain',
#   'problem',
#   'appolog',
#   'give',
#   'govt',
#   'student',
#   'loan',
#   'tel',
#   'worthless',
#   'continu',
#   'behavior'],
#  ['auto', 'loan', 'compani', 'call', 'blackhawk', 'auto', 'loan'],
#  ['onli', '2', 'month', 'pay', 'vehicl', 'got', 'total'],
#  ['insur',
#   'paid',
#   'amount',
#   'wa',
#   'worth',
#   'wa',
#   '60000',
#   'balanc',
#   'remain',
#   'sent',
#   'check',
#   'week',
#   'pay'],
#  ['tri',
#   'get',
#   'loan',
#   'new',
#   'car',
#   'nt',
#   'abl',
#   'becaus',
#   'blackhawk',
#   'auto',
#   'loan',
#   'took',
#   'veri',
#   'veri',
#   'long',
#   'time',
#   'process',
#   'check',
#   'show',
#   'left',
#   'auto',
#   'loan',
#   'unpaid',
#   '4',
#   'month'],
#  ['blackhawk',
#   'auto',
#   'loan',
#   'longer',
#   'busi',
#   'phone',
#   'number',
#   'provid',
#   'get',
#   'inform',
#   'compani',
#   'bought',
#   'servic'],
#  ['find', 'anyth', 'help', 'fix', 'thi', 'credit', 'terribl'],
#  ['seen', 'hard', 'inquiri', 'certain', 'lender', 'permiss'],
#  ['follow',
#   'alli',
#   'bank',
#   'instruct',
#   'phone',
#   'call',
#   'download',
#   'complet',
#   'pdf',
#   'form',
#   'add',
#   'wife',
#   'account',
#   'owner',
#   'save',
#   'account'],
#  ['follow',
#   'form',
#   'instruct',
#   'submit',
#   'alli',
#   'bank',
#   'onlin',
#   'secur',
#   'messag',
#   'system'],
#  ['wa',
#   'chang',
#   'ownership',
#   'statu',
#   'submit',
#   'repli',
#   'origin',
#   'secur',
#   'messag'],
#  ['alli',
#   'repli',
#   'wa',
#   'provid',
#   'alreadysubmit',
#   'account',
#   'inform',
#   'form',
#   'account',
#   'number'],
#  ['provid', 'thi'],
#  ['alli',
#   'told',
#   'submit',
#   'paperwork',
#   'neglect',
#   'see',
#   'origin',
#   'pdf',
#   'submiss'],
#  ['repli', 'check', 'origin', 'record', 'becaus', 'thi', 'alreadi', 'file'],
#  ['thi',
#   'second',
#   'instanc',
#   'alli',
#   'lose',
#   'form',
#   'give',
#   'instruct',
#   'submit',
#   'onlin',
#   'via',
#   'secur',
#   'messag',
#   'format'],
#  ['thi',
#   'becaus',
#   'prefer',
#   'send',
#   'document',
#   'encrypt',
#   'usernam',
#   'password',
#   'rather',
#   'fax'],
#  ['secur', 'messag', 'leav', 'paper', 'trail'],
#  ['first',
#   'troubl',
#   'thi',
#   'wa',
#   'wa',
#   'tri',
#   'add',
#   'wife',
#   'check',
#   'account'],
#  ['thi',
#   'second',
#   'time',
#   'show',
#   'utter',
#   'ignor',
#   'thi',
#   'secur',
#   'messag',
#   'platform',
#   'set',
#   'suggest',
#   'use'],
#  ['ha',
#   'two',
#   'month',
#   'wife',
#   'still',
#   'doe',
#   'see',
#   'save',
#   'account',
#   'want',
#   'join',
#   'us',
#   'newlyw'],
#  ['thi',
#   'complaint',
#   'toward',
#   'coinbasecom',
#   'account',
#   'email',
#   'issu',
#   '2018',
#   'sent',
#   'aaproxim',
#   'btc',
#   'usd',
#   'wallet',
#   'address'],
#  ['show', 'wa', 'receiv', 'pend'],
#  ['read', 'onlin', 'requir', '6', 'confirm'],
#  ['ha', '14', 'day', 'transact', 'ha', 'aproxim', 'confirm'],
#  ['request', 'transact', 'fix'],
#  ['thi', 'inconvienc', 'standard', 'consum'],
#  ['thank'],
#  ['serv'],
#  ['famili',
#   'receiv',
#   'order',
#   'report',
#   'exact',
#   'date',
#   'departur',
#   'undetermin'],
#  ['permit', 'take', 'vehicl', 'us'],
#  ['compani',
#   'ship',
#   'vehicl',
#   'requir',
#   'either',
#   'clear',
#   'titl',
#   'letter',
#   'approv',
#   'vehicl',
#   'lien',
#   'older'],
#  ['sometim',
#   'contact',
#   'alli',
#   'bank',
#   'request',
#   'letter',
#   'author',
#   'ship',
#   'vehicl'],
#  ['wa', 'told', 'would', 'provid', 'letter'],
#  ['purchas', 'vehicl', 'back'],
#  ['total', 'cost', 'vehicl', 'wa', '1700000'],
#  ['vehicl',
#   'current',
#   'worth',
#   '600000',
#   'current',
#   'owe',
#   'approxim',
#   '700000'],
#  ['fund', 'avail', 'immedi', 'pay', 'remain', 'balanc'],
#  ['contact',
#   'bank',
#   'ask',
#   'refinanc',
#   'vehicl',
#   'wa',
#   'told',
#   'wo',
#   'nt',
#   'becaus',
#   'valu',
#   'car',
#   'less',
#   'amount',
#   'still',
#   'owe'],
#  ['current', 'payment', 'car', 'loan'],
#  ...]

# %% [markdown]
# # Embedding

# %% [markdown]
# ## Word2Vec (Pretrained Google News)

# %%
# Importing pre-trained model, updating vocab 
# and training the model (takes long to run)
#runtime without google: 18''
model_2 = Word2Vec(size=300, min_count=1, window = 5)
model_2.build_vocab(corpus)
total_examples = model_2.corpus_count

# #for testing commented out:
# model_pt = gensim.models.KeyedVectors.load_word2vec_format('/home/sevi/Desktop/Work/PropulsionDS/Pretrained/GoogleNews-vectors-negative300.bin', binary=True)
# model_2.build_vocab([list(model_pt.vocab.keys())], update=True)
# model_2.intersect_word2vec_format('/home/sevi/Desktop/Work/PropulsionDS/Pretrained/GoogleNews-vectors-negative300.bin', binary=True, lockf=1.0)

# intersect_word2vec_format() will let you bring vectors from an external file into a model that's already had its own vocabulary initialized
# see https://tedboy.github.io/nlps/generated/generated/gensim.models.Word2Vec.intersect_word2vec_format.html
model_2.train(corpus, total_examples=total_examples, epochs=model_2.iter)
# Out:
# /home/sevi/anaconda3/envs/propulsion2020/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   from ipykernel import kernelapp as app
# (470115, 548965)

# %%
#model_2.wv.vectors contains 26'668 vectors of length 300
print(len(model_2.wv.vectors))
print(len(model_2.wv.vectors[0]))
print(len(model_2.wv.vocab))
# Out:
# 5586
# 300
# 5586

# %% [markdown]
# ## TF-IDF

# %%
doc_clean = [' '.join(document) for document in doc_sent_clean]

# %%
#SK02
#this function creates the (for now only global) TF-IDF weights for each word.
def calc_tf_idf(cleaned_doc_str = None):
    '''
    This function expects as an input for each document the already cleaned string wrapped in a list. 
    Then it returns all the TF-IDF scores for each word and document in the matrix tfid_matrix.
    
    Attributes:
    - cleaned_doc_str: List of strings
            Default = None
            This list contains for each document the string of its content. The string is expected to already be cleaned and stopwords removed.
    '''
     
    #Calculate TF-IDF score for all words in the corpus
    tfidf = TfidfVectorizer(
          sublinear_tf=True
        , min_df=1
        , norm='l2'
        , encoding='latin-1'
        , ngram_range=(1,1)  #considering only 1-grams for now
        , token_pattern= '(?u)\\b\\w+\\b' #changed from default in order to also include single letters in case they appear in the corpus.
        , tokenizer=nltk.word_tokenize #we pass the corpus as words already.
        , stop_words=None #we already removed stopwords
    ) 
    tfidf_matrix = tfidf.fit_transform(cleaned_doc_str)#.toarray()
    
        
    if(not(len(tfidf.get_feature_names()) == len(model_2.wv.vocab.keys()))):
        warnings.warn('The count of vocabulary from the word embedding does not coincide with the TF-IDF Vectorizer features.')
    
    return tfidf
    #None
    #tfidf_matrix contains TF-IDF scores for each document (in the rows) and word (in the columns)
    #tfidf.get_feature_names() gives you the words in the order

# %% [raw]
# #not in use for now
# def calc_embedding(doc_sent_clean = None, sentEmbedding = True):
#     '''
#     This function calculates the embedding matrix for the sentence embedding or word embedding with or without TF-IDF weights.
#
#     Attibutes:
#     - doc_sent_clean: 2d-array
#             Default = None
#             list of lists where each word represents
#     - sentEmbedding: boolean
#             Default = True
#             if set to True the embedding is calculated on a sentence level. Otherwise on word-level
#     '''
#
#     doc_clean = [' '.join(document) for document in doc_sent_clean]
#
#     doc_word_tfidf = calc_tf_idf(doc_clean)
#     nr_docs = doc_word_tfidf.shape[0]
#     #nr_words = len(doc_word_tfidf.index)
#
#     embedding_matrix = np.zeros((nr_docs + 1, 300))
#
#     #calculate embedding for sentences:
#     if(sentEmbedding):
#         '''to be continued'''
#
#
#     #calculate embedding for words
#     else:
#         #average all TF-idfs for all documents:
#         tfidf_matrix = pd.DataFrame(data = tfidf_matrix.mean(axis = 0)[0]
#                                     , columns = tfidf.get_feature_names()
#                                     , index = ['TFIDF']
#                                     )
#
#         for i, token in enumerate(global_word_tfidf.columns):
#               embedding_matrix[i] = model_2.wv.get_vector(token) * global_word_tfidf[token].values[0]
#         #embedding_matrix is 26'668 x 300 matrix

# %%
def get_sentence_vector(sent_clean_token=None, model=None, fitted_tfidf=None):
    '''
    This function is to average all words vectors in a given sentence.

    Parameters
    ----------
    sent_clean_token : string
            a string representing a sentence
    model : model
            a word embedding model (f.e. Word2Vec) featuring model['example_word']
    fitted_tfidf : fitted TfidfVectorizer
            pass the TF-IDF Vectorizer fitted to the dictionary
    '''
    #words = word_tokenize(clean_sentence(sentence))

    sent_len = len(sent_clean_token)
    total_weight = fitted_tfidf.vocabulary_[sent_clean_token[0]]
    sentenceVec = model.wv[sent_clean_token[0]] * fitted_tfidf.vocabulary_[sent_clean_token[0]]
    for i in range(1, sent_len):
        sentenceVec = sentenceVec + model.wv[sent_clean_token[i]] * fitted_tfidf.vocabulary_[sent_clean_token[i]]
        total_weight += fitted_tfidf.vocabulary_[sent_clean_token[i]]
                            
    return sentenceVec/total_weight

# %%
doc_clean = [' '.join(document) for document in doc_sent_clean]    
doc_word_tfidf = calc_tf_idf(doc_clean)
sent_clean = [sentence for document in doc_sent_clean for sentence in document]

# %%
#nr_docs = doc_word_tfidf.shape[0]    
sent_embedding_matrix = np.zeros((len(corpus), 300))

#embedding_matrix is 26'668 x 300 matrix 
for idx, sent in enumerate(corpus):
    sent_embedding_matrix[idx] = get_sentence_vector(sent,model_2,doc_word_tfidf)

# %%
print(len(sent_embedding_matrix[0]))
print(len(sent_embedding_matrix))
# Out:
# 300
# 10960

# %% [markdown]
# # Active Learning

# %% [markdown]
# ## Input Preparation

# %%
#SK03
feature_size = 500
tokenizer = Tokenizer(num_words = feature_size, split = ' ')
# fit the tokenizer on our text
tokenizer.fit_on_texts(sent_clean) #SK03 changed to be applied son sent_clean instead of features (which is grouped by docs)

# %%
# put the tokens in a matrix
X = tokenizer.texts_to_sequences(sent_clean)
X = pad_sequences(X)
#len(X) = number of sentences in all docs

# %%
#SK04
def calc_target_per_sent(sentence_per_doc = None, target_original = None):
    
    current_target_idx = 0
    new_target = pd.DataFrame()
    for doc in sentence_per_doc:
        for sentence in doc:
            new_target = new_target.append(target.iloc[current_target_idx:current_target_idx+1])
            
        current_target_idx += 1

        
    return new_target.reset_index(drop = True)

# %%
target = calc_target_per_sent(doc_sent_clean, target)

# %%
# prepare the labels
y = pd.get_dummies(target)

# %%
print(len(X))
print(len(y))

# %%
# split in train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=False)

# %% [markdown]
# ## Define and Run Model

# %%
# init model
model = Sequential()
# emmbed word vectors
model.add(Embedding(len(model_2.wv.vocab) + 1 ,
                    300,
                    input_length  = X.shape[1],
                    weights = [embedding_matrix],
                    trainable=False))
# learn the correlations
model.add(LSTM(300,return_sequences=False))
model.add(Dense(12,activation="softmax")) 
# output model skeleton
model.summary()
model.compile(optimizer="nadam",loss="categorical_crossentropy",metrics=['acc'])

# %%
batch = 64
epochs = 50
model.fit(X_train,y_train,batch,epochs)

# %%
model.evaluate(X_test,y_test)
