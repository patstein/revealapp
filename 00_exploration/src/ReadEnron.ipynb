# %%
import pandas as pd

# %%
zoneannotations = pd.read_table('../data/raw/Enron Annotated DataSet/zonannotations', sep=',', lineterminator=';')

# %%
zoneannotations
# Out:
#         id  messageid  lineid  userid               datetime  annvalue errorid
# 0      101      31767    4700       1  '2008-07-21 10:32:49'         4     'n'
# 1      102      31767    4701       1  '2008-07-21 10:32:49'         0     'n'
# 2      103      31767    4702       1  '2008-07-21 10:32:49'         0     'n'
# 3      104      31767    4703       1  '2008-07-21 10:32:49'         0     'n'
# 4      105      31767    4704       1  '2008-07-21 10:32:49'         0     'n'
# ...    ...        ...     ...     ...                    ...       ...     ...
# 2516  2617     181294   22913       1  '2008-07-25 06:34:42'         7    'x7'
# 2517  2618     181294   22914       1  '2008-07-25 06:34:42'         7    'x7'
# 2518  2619     181294   22915       1  '2008-07-25 06:34:42'         7    'x7'
# 2519  2620     181294   22916       1  '2008-07-25 06:34:42'         7    'x7'
# 2520  2621     181294   22917       1  '2008-07-25 06:34:42'         7    'x7'
#
# [2521 rows x 7 columns]

# %%
zoneannotations[zoneannotations['annvalue']==5]
# Out:
#         id  messageid  lineid  userid               datetime  annvalue errorid
# 6      107      31767    4706       1  '2008-07-21 10:32:49'         5     'n'
# 115    216     211886   26741       1  '2008-07-21 10:41:03'         5     'n'
# 128    229      65736    9315       1  '2008-07-21 10:42:41'         5     'n'
# 129    230      65736    9316       1  '2008-07-21 10:42:41'         5     'n'
# 174    275     120006   15456       1  '2008-07-21 10:43:37'         5     'n'
# 440    541     252788   31616       1  '2008-07-21 10:48:20'         5     'n'
# 451    552     141756   18350       1  '2008-07-21 10:49:21'         5     'n'
# 452    553     141756   18351       1  '2008-07-21 10:49:21'         5     'n'
# 491    592      89396   11922       1  '2008-07-21 10:51:25'         5     'n'
# 508    609      48128    6475       1  '2008-07-21 10:53:06'         5     'n'
# 689    790      55710    8085       1  '2008-07-21 10:55:19'         5     'n'
# ...

# %%
zoneannotations.groupby('annvalue').agg({'id':['count']})
# Out:
#             id
#          count
# annvalue
# 0          655
# 1          128
# 2           22
# 3           57
# 4           20
# 5           51
# 6         1144
# 7          432
# 8           12

# %%
zonelines = pd.read_table('../data/raw/Enron Annotated DataSet/zonelines', sep=',', lineterminator='}')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-20-9dc5d48c5051> in <module>
# ----> 1 zonelines = pd.read_table('../data/raw/Enron Annotated DataSet/zonelines', sep=',', lineterminator='}')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...
