# %%
import pandas as pd
pd.options.mode.chained_assignment = None 
import numpy as np
import re
import nltk
import os
import smart_open
import collections
import scipy.stats as stats
import tensorflow as tf
import gensim

from gensim.models.word2vec import Word2Vec
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.test.utils import common_texts
from gensim.test.utils import get_tmpfile

from tensorflow import keras
from tensorflow.keras import Sequential, Model
from tensorflow.keras import backend as K
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam, Adadelta, Nadam #schedules
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Embedding, Dense, Flatten, LSTM, Conv1D, Conv2D, GlobalAveragePooling1D, Conv2D, ZeroPadding2D
from tensorflow.keras.layers import Bidirectional, GlobalAveragePooling2D, GlobalAveragePooling3D, BatchNormalization, Dropout
from tensorflow.keras.layers import Subtract, Add, Multiply, Activation, Input, Concatenate, Reshape 
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from keras import optimizers

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib inline

from nltk import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem.snowball import SnowballStemmer

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, roc_auc_score
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import MultinomialNB
#from sklearn.model_selection import GridSearchCV, RandomSearch
from sklearn.ensemble import RandomForestClassifier

from sklearn import svm, tree
import xgboost
# Out:
# Using TensorFlow backend.

# %%
os.chdir('/Users/patrickrs/Documents/GitLab/revealapp/00_exploration')

# %% [markdown]
# ### Get the data

# %%
data = pd.read_csv('data/SICK_train.txt', sep="\t")

# %%
data
# Out:
#       pair_ID                                         sentence_A  \
# 0           1  A group of kids is playing in a yard and an ol...
# 1           2  A group of children is playing in the house an...
# 2           3  The young boys are playing outdoors and the ma...
# 3           5  The kids are playing outdoors near a man with ...
# 4           9  The young boys are playing outdoors and the ma...
# ...       ...                                                ...
# 4495     9993                    A door is being opened by a man
# 4496     9997                   Someone is boiling okra in a pot
# 4497     9998  The man is singing heartily and playing the gu...
# 4498     9999        A man in blue has a yellow ball in the mitt
# 4499    10000               Three dogs are resting on a sidewalk
#
#                                              sentence_B  relatedness_score  \
# 0     A group of boys in a yard is playing and a man...                4.5
# 1     A group of kids is playing in a yard and an ol...                3.2
# 2     The kids are playing outdoors near a man with ...                4.7
# 3     A group of kids is playing in a yard and an ol...                3.4
# 4     A group of kids is playing in a yard and an ol...                3.7
# ...                                                 ...                ...
# 4495  A bald man in a band is playing guitar in the ...                1.1
# 4496                   The man is not playing the drums                1.0
# 4497  A bicyclist is holding a bike over his head in...                1.0
# 4498                      A man is jumping rope outside                1.2
# 4499         The woman with a knife is slicing a pepper                1.0
#
#      entailment_judgment
# 0                NEUTRAL
# 1                NEUTRAL
# 2             ENTAILMENT
# 3                NEUTRAL
# 4                NEUTRAL
# ...                  ...
# 4495             NEUTRAL
# 4496             NEUTRAL
# 4497             NEUTRAL
# 4498             NEUTRAL
# 4499             NEUTRAL
#
# [4500 rows x 5 columns]

# %% [markdown]
# ### Cleaning the data

# %%
nltk.download('stopwords')
STOP_WORDS = nltk.corpus.stopwords.words('english')

def clean_sentence(val):
    "remove chars that are not letters or numbers, downcase, then remove stop words"
    regex = re.compile('([^\s\w]|_)+')
    sentence = regex.sub('', val).lower()
    sentence = re.sub("xxxx", "", sentence)
    sentence = re.sub("xxx", "", sentence)
    sentence = re.sub("xx", "", sentence)
    sentence = re.sub("\s\s+", " ", sentence)
       
    ''' stemming of words (seems not to affect accuracy, but should make things faster
    porter = PorterStemmer()
    words = word_tokenize(sentence)
    sentence = " ".join([porter.stem(word) for word in words])
     ''' 
    sentence = sentence.split(" ")
    for word in list(sentence):
        if word in STOP_WORDS:
            sentence.remove(word)  
    sentence = " ".join(sentence)
    
    return sentence
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/patrickrs/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data['sentence_A'] = [clean_sentence(sentence) for sentence in data['sentence_A']]

# %%
data['sentence_B'] = [clean_sentence(sentence) for sentence in data['sentence_B']]

# %%
data.head()
# Out:
#    pair_ID                                         sentence_A  \
# 0        1  group kids playing yard old man standing backg...
# 1        2  group children playing house man standing back...
# 2        3     young boys playing outdoors man smiling nearby
# 3        5               kids playing outdoors near man smile
# 4        9     young boys playing outdoors man smiling nearby
#
#                                           sentence_B  relatedness_score  \
# 0    group boys yard playing man standing background                4.5
# 1  group kids playing yard old man standing backg...                3.2
# 2               kids playing outdoors near man smile                4.7
# 3  group kids playing yard old man standing backg...                3.4
# 4  group kids playing yard old man standing backg...                3.7
#
#   entailment_judgment
# 0             NEUTRAL
# 1             NEUTRAL
# 2          ENTAILMENT
# 3             NEUTRAL
# 4             NEUTRAL

# %% [markdown]
# ### Import word2vec from google

# %%
def build_corpus(data):
    "Creates a list of lists containing words from each sentence"
    corpus = []
    for content in data:
        corpus_temp = nltk.word_tokenize(content)
        corpus.append(corpus_temp)
    return corpus

corpus = build_corpus(pd.concat([data['sentence_A'], data['sentence_B']]))

# %%
corpus
# Out:
# [['group', 'kids', 'playing', 'yard', 'old', 'man', 'standing', 'background'],
#  ['group', 'children', 'playing', 'house', 'man', 'standing', 'background'],
#  ['young', 'boys', 'playing', 'outdoors', 'man', 'smiling', 'nearby'],
#  ['kids', 'playing', 'outdoors', 'near', 'man', 'smile'],
#  ['young', 'boys', 'playing', 'outdoors', 'man', 'smiling', 'nearby'],
#  ['two', 'dogs', 'fighting'],
#  ['brown', 'dog', 'attacking', 'another', 'animal', 'front', 'man', 'pants'],
#  ['brown', 'dog', 'attacking', 'another', 'animal', 'front', 'man', 'pants'],
#  ['nobody', 'riding', 'bicycle', 'one', 'wheel'],
#  ['person', 'riding', 'bicycle', 'one', 'wheel'],
#  ['person', 'black', 'motorbike', 'tricks', 'jacket'],
#  ['man', 'jersey', 'dunking', 'ball', 'basketball', 'game'],
#  ['man', 'jersey', 'dunking', 'ball', 'basketball', 'game'],
#  ['player', 'dunking', 'basketball', 'net', 'crowd', 'background'],
#  ['two', 'people', 'kickboxing', 'spectators', 'watching'],
#  ['two', 'young', 'women', 'sparring', 'kickboxing', 'fight'],
#  ['two', 'young', 'women', 'sparring', 'kickboxing', 'fight'],
#  ['two', 'people', 'kickboxing', 'spectators', 'watching'],
#  ['two', 'women', 'sparring', 'kickboxing', 'match'],
#  ['three', 'boys', 'jumping', 'leaves'],
#  ['three', 'kids', 'sitting', 'leaves'],
#  ['children', 'red', 'shirts', 'playing', 'leaves'],
#  ['children', 'red', 'shirts', 'playing', 'leaves'],
#  ['two', 'angels', 'making', 'snow', 'lying', 'children'],
#  ['two', 'children', 'lying', 'snow', 'drawing', 'angels'],
#  ['two', 'people', 'snowsuits', 'lying', 'snow', 'making', 'snow', 'angels'],
#  ['two', 'children', 'lying', 'snow', 'making', 'snow', 'angels'],
#  ['people',
#   'wearing',
#   'costumes',
#   'gathering',
#   'forest',
#   'looking',
#   'direction'],
#  ['people',
#   'wearing',
#   'costumes',
#   'gathering',
#   'forest',
#   'looking',
#   'direction'],
#  ['people', 'looking', 'costumes', 'gathered', 'vicinity', 'forest'],
#  ['little', 'girl', 'looking', 'woman', 'costume'],
#  ['little', 'girl', 'looking', 'woman', 'costume'],
#  ['young', 'girl', 'looking', 'woman', 'costume'],
#  ['people',
#   'wearing',
#   'costumes',
#   'gathering',
#   'forest',
#   'looking',
#   'direction'],
#  ['people',
#   'wearing',
#   'costumes',
#   'gathering',
#   'forest',
#   'looking',
#   'direction'],
#  ['lone', 'biker', 'jumping', 'air'],
#  ['biker', 'jumping', 'air'],
#  ['man', 'jumping', 'empty', 'pool'],
#  ['man', 'jumping', 'empty', 'pool'],
#  ['lone', 'biker', 'jumping', 'air'],
#  ['mans', 'jumper', 'empty', 'pool'],
#  ['lone', 'biker', 'jumping', 'air'],
#  ['four', 'kids', 'backbends', 'park'],
#  ['four', 'children', 'backbends', 'gym'],
#  ['four', 'girls', 'backbends', 'playing', 'garden'],
#  ['man', 'playing', 'running', 'ball', 'hands'],
#  ['two', 'groups', 'people', 'playing', 'football'],
#  ['two', 'teams', 'competing', 'baseball', 'game'],
#  ['player', 'running', 'ball'],
#  ['five', 'wooden', 'stands', 'front', 'childs', 'hut'],
#  ['five', 'kids', 'standing', 'close', 'together', 'one', 'kid', 'gun'],
#  ['five', 'kids', 'standing', 'close', 'together', 'none', 'kids', 'gun'],
#  ['five', 'children', 'standing', 'wooden', 'hut'],
#  ['five', 'wooden', 'stands', 'front', 'childs', 'hut'],
#  ['old', 'man', 'sitting', 'field'],
#  ['man', 'sitting', 'field'],
#  ['person', 'wearing', 'hat', 'sitting', 'grass'],
#  ['person', 'sitting', 'wearing', 'grass', 'hat'],
#  ['person', 'sitting', 'wearing', 'grass', 'hat'],
#  ['man', 'sitting', 'field'],
#  ['current', 'ridden', 'group', 'friends', 'raft'],
#  ['group', 'friends', 'riding', 'current', 'raft'],
#  ['current', 'ridden', 'group', 'friends', 'raft'],
#  ['group', 'friends', 'riding', 'current', 'raft'],
#  ['deer', 'jumping', 'fence'],
#  ['people', 'walking', 'inside', 'building', 'many', 'murals'],
#  ['several', 'people', 'front', 'colorful', 'building'],
#  ['people', 'walking', 'outside', 'building', 'many', 'murals'],
#  ['people', 'walking', 'outside', 'building', 'several', 'murals'],
#  ['family', 'watching', 'little', 'boy', 'hitting', 'baseball'],
#  ['child', 'hitting', 'baseball'],
#  ['child', 'missing', 'baseball'],
#  ['purple',
#   'crowd',
#   'people',
#   'eating',
#   'various',
#   'red',
#   'lit',
#   'restaurant',
#   'tables'],
#  ['large', 'group', 'asian', 'people', 'eating', 'restaurant'],
#  ['purple',
#   'crowd',
#   'people',
#   'eating',
#   'various',
#   'red',
#   'lit',
#   'restaurant',
#   'tables'],
#  ['various',
#   'people',
#   'eating',
#   'red',
#   'tables',
#   'crowded',
#   'restaurant',
#   'purple',
#   'lights'],
#  ['motorcycle', 'rider', 'standing', 'seat', 'white', 'motorcycle'],
#  ['nobody', 'motorcycle', 'standing', 'seat'],
#  ['motorcyclist', 'riding', 'motorbike', 'dangerously', 'along', 'roadway'],
#  ['motorcyclist', 'riding', 'motorbike', 'along', 'roadway'],
#  ['man', 'helmet', 'painted', 'red', 'riding', 'blue', 'motorcycle', 'road'],
#  ['motorcyclist',
#   'without',
#   'helmet',
#   'waiting',
#   'blue',
#   'motorcycle',
#   'near',
#   'road'],
#  ['two', 'dogs', 'playing', 'tree'],
#  ['two', 'dogs', 'playing', 'tree'],
#  ['two', 'dogs', 'playing', 'tree'],
#  ['girl', 'white', 'dancing'],
#  ['girl', 'white', 'dancing'],
#  ['girl', 'wearing', 'white', 'clothes', 'dancing'],
#  ['blond', 'girl', 'dancing', 'front', 'sound', 'equipment'],
#  ['three', 'asian', 'kids', 'dancing', 'man', 'looking'],
#  ['three', 'asian', 'kids', 'dancing', 'man', 'looking'],
#  ['children', 'family', 'playing', 'waiting'],
#  ['children', 'family', 'patiently', 'playing', 'waiting'],
#  ['children', 'playing', 'waiting'],
#  ['woman', 'wearing', 'egyptian', 'hat', 'head'],
#  ['woman', 'wearing', 'egyptian', 'headdress'],
#  ['black', 'woman', 'wearing', 'glasses', 'headdress'],
#  ['woman', 'wearing', 'egyptian', 'hat', 'head'],
#  ['hiker', 'top', 'mountain', 'dancing'],
#  ['man', 'rock', 'high', 'trees', 'standing', 'strange', 'position'],
#  ['hiker', 'top', 'mountain', 'dancing'],
#  ['hiker', 'top', 'mountain', 'dancing'],
#  ['man', 'rock', 'high', 'trees', 'standing', 'strange', 'position'],
#  ['hiker', 'dancing', 'top', 'mountain'],
#  ['brown', 'horse', 'near', 'red', 'barrel', 'rodeo'],
#  ['brown', 'horse', 'near', 'red', 'barrel', 'rodeo'],
#  ['cowgirl', 'riding', 'brown', 'horse', 'cornering', 'barrel'],
#  ['cowgirl', 'riding', 'horse', 'corners', 'barrel'],
#  ['boy', 'standing', 'cold', 'water'],
#  ['boy', 'sitting', 'near', 'blue', 'ocean'],
#  ['boy', 'standing', 'water'],
#  ['boy', 'wading', 'blue', 'ocean'],
#  ['man', 'playing', 'guitar', 'stage'],
#  ['man', 'playing', 'guitar', 'stage'],
#  ['man', 'playing', 'guitar', 'stage'],
#  ['man', 'playing', 'guitar', 'stage'],
#  ['several', 'children', 'sitting', 'knees', 'raised'],
#  ['two', 'young', 'girls', 'sitting', 'ground'],
#  ['two', 'girls', 'lying', 'ground'],
#  ['nude', 'lady', 'walking', 'front', 'crowd', 'body', 'paint'],
#  ['nude', 'lady', 'walking', 'front', 'crowd', 'body', 'paint'],
#  ['young', 'topless', 'woman', 'covered', 'paint'],
#  ['nude', 'lady', 'walking', 'front', 'crowd', 'body', 'paint'],
#  ['nude', 'crowd', 'body', 'paint', 'walking', 'front', 'lady'],
#  ['nude', 'lady', 'walking', 'front', 'crowd', 'body', 'paint'],
#  ['group', 'people', 'near', 'ocean'],
#  ['crowd', 'people', 'near', 'water'],
#  ['group',
#   'children',
#   'uniforms',
#   'standing',
#   'gate',
#   'one',
#   'kissing',
#   'mother'],
#  ['group',
#   'mothers',
#   'uniforms',
#   'standing',
#   'near',
#   'children',
#   'one',
#   'kissing',
#   'gate'],
#  ['man', 'parking', 'lot', 'playing', 'tennis', 'large', 'wall'],
#  ['man', 'parking', 'lot', 'playing', 'tennis', 'large', 'wall'],
#  ['man', 'parking', 'lot', 'playing', 'tennis', 'friend'],
#  ['group', 'people', 'beach'],
#  ['group', 'people', 'beach'],
#  ['man', 'woman', 'two', 'girls', 'walking', 'beach'],
#  ['group', 'people', 'beach'],
#  ['man', 'woman', 'two', 'girls', 'walking', 'beach'],
#  ['man', 'woman', 'two', 'girls', 'walking', 'beach'],
#  ['schoolgirl', 'black', 'bag', 'crowded', 'train'],
#  ['girl', 'black', 'bag', 'crowded', 'train'],
#  ['girl', 'black', 'bag', 'crowded', 'train'],
#  ['asian', 'woman', 'crowd', 'carrying', 'black', 'bag'],
#  ['girl', 'black', 'bag', 'crowded', 'train'],
#  ['schoolgirl', 'black', 'bag', 'crowded', 'train'],
#  ['dog', 'chasing', 'another', 'holding', 'stick', 'mouth'],
#  ['two', 'dogs', 'running', 'carrying', 'toy', 'mouths'],
#  ['dog', 'chasing', 'another', 'holding', 'piece', 'wood', 'mouth'],
#  ['two', 'dogs', 'running', 'carrying', 'object', 'mouths'],
#  ['dog', 'chasing', 'another', 'holding', 'stick', 'mouth'],
#  ['dirty', 'soccer', 'ball', 'rolling', 'goal', 'net'],
#  ['soccer', 'ball', 'rolling', 'goal', 'net'],
#  ['person', 'plays', 'soccer', 'kicking', 'ball', 'goal'],
#  ['soccer', 'ball', 'rolling', 'goal', 'net'],
#  ['soccer', 'ball', 'rolling', 'goal', 'net'],
#  ['man', 'sitting', 'chair', 'rubbing', 'eyes'],
#  ['man', 'tattoos', 'lounging', 'couch', 'holding', 'pencil'],
#  ['man', 'tattoos', 'lounging', 'couch', 'holding', 'pencil'],
#  ['man', 'tattoos', 'holding', 'couch', 'pencil'],
#  ['man', 'sitting', 'chair', 'rubbing', 'eyes'],
#  ['man', 'tattoos', 'holding', 'couch', 'pencil'],
#  ['man', 'resting', 'chair', 'rubbing', 'eyes'],
#  ['man', 'tattoos', 'lounging', 'couch', 'holding', 'pencil'],
#  ['man', 'tattoos', 'lounging', 'couch', 'holding', 'pencil'],
#  ['brown', 'white', 'dog', 'running', 'tall', 'grass'],
#  ['white', 'tan', 'dog', 'running', 'tall', 'green', 'grass'],
#  ['man',
#   'paint',
#   'covered',
#   'clothes',
#   'sitting',
#   'outside',
#   'busy',
#   'area',
#   'writing',
#   'something'],
#  ['man',
#   'wearing',
#   'clothes',
#   'covered',
#   'paint',
#   'sitting',
#   'outside',
#   'busy',
#   'area',
#   'writing',
#   'something'],
#  ['sitting',
#   'man',
#   'busy',
#   'writing',
#   'something',
#   'area',
#   'covered',
#   'paint'],
#  ['man', 'sitting', 'near', 'bike', 'writing', 'note'],
#  ['man',
#   'wearing',
#   'clothes',
#   'covered',
#   'paint',
#   'sitting',
#   'outside',
#   'busy',
#   'area',
#   'writing',
#   'something'],
#  ['man', 'writing', 'note', 'near', 'bike'],
#  ['man', 'sitting', 'near', 'bike', 'writing', 'note'],
#  ['group', 'scouts', 'camping', 'grass'],
#  ['people', 'walking'],
#  ['people', 'walking'],
#  ['group', 'scouts', 'hiking', 'grass'],
#  ['two', 'men', 'taking', 'break', 'trip', 'snowy', 'road'],
#  ['two', 'men', 'bikes', 'side', 'snowy', 'road'],
#  ['two', 'men', 'holding', 'fishing', 'poles', 'fishing', 'tackle'],
#  ['two', 'men', 'holding', 'fishing', 'poles'],
#  ['two', 'men', 'holding', 'fishing', 'poles'],
#  ['man', 'standing', 'near', 'water', 'holding', 'fishing', 'poles'],
#  ['helmeted', 'girl', 'riding', 'bike'],
#  ['woman', 'performing', 'trick', 'ramp', 'bicycle'],
#  ['woman', 'performing', 'trick', 'ramp', 'bicycle'],
#  ['helmeted', 'girl', 'perching', 'bike'],
#  ['girl', 'helmet', 'perching', 'bike'],
#  ['helmeted', 'girl', 'riding', 'bike'],
#  ['woman', 'performing', 'trick', 'ramp', 'bicycle'],
#  ['blonds', 'girl', 'surfing'],
#  ['lady', 'surfing', 'riding', 'wave'],
#  ['woman', 'surfing'],
#  ['lady', 'surfing', 'riding', 'wave'],
#  ['blond', 'girl', 'waves', 'riding'],
#  ['two', 'children', 'adult', 'standing', 'next', 'tree', 'limb'],
#  ['two', 'children', 'adult', 'standing', 'next', 'tree', 'limb'],
#  ['two', 'children', 'adult', 'standing', 'next', 'tree', 'limb'],
#  ['man', 'dressed', 'black', 'riding', 'bike'],
#  ['man', 'performing', 'stunts', 'green', 'bicycle'],
#  ['man', 'dressed', 'black', 'riding', 'green', 'bike'],
#  ['boy', 'holding', 'squirt', 'gun'],
#  ['laughing',
#   'child',
#   'holding',
#   'water',
#   'gun',
#   'getting',
#   'sprayed',
#   'water'],
#  ['child', 'holding', 'water', 'gun', 'getting', 'sprayed', 'water'],
#  ['child', 'gun', 'sprays', 'water', 'laughing', 'getting', 'hit', 'boys'],
#  ['two', 'daschunds', 'playing', 'red', 'ball'],
#  ['two', 'cats', 'playing', 'red', 'ball'],
#  ['two', 'brown', 'dogs', 'fighting', 'red', 'ball', 'playing', 'grass'],
#  ['dog', 'playing', 'red', 'ball'],
#  ['black', 'white', 'dog', 'running', 'person', 'stands', 'behind'],
#  ['little', 'dog', 'sprinting', 'person', 'owns', 'trying', 'catch'],
#  ['black', 'white', 'dog', 'running', 'person', 'stands', 'behind'],
#  ['black', 'white', 'dog', 'running', 'person', 'stands', 'behind'],
#  ['black', 'white', 'dog', 'isnt', 'running', 'person', 'standing', 'behind'],
#  ['black',
#   'person',
#   'running',
#   'along',
#   'white',
#   'stand',
#   'dog',
#   'barks',
#   'behind'],
#  ['man', 'wearing', 'dyed', 'black', 'shirt', 'sitting', 'table', 'laughing'],
#  ['man', 'wearing', 'dyed', 'black', 'shirt', 'sitting', 'table', 'laughing'],
#  ['laughing', 'man', 'dyeing', 'shirt', 'black', 'table', 'can', 'not', 'sit'],
#  ['black', 'shirt', 'worn', 'man', 'sitting', 'table', 'laughing'],
#  ['man', 'sitting', 'tables', 'comfortable', 'discussion'],
#  ['man', 'sitting', 'comfortably', 'table'],
#  ['woman',
#   'wearing',
#   'pink',
#   'boa',
#   'riding',
#   'bicycle',
#   'bridge',
#   'built',
#   'pedestrians'],
#  ['woman',
#   'taking',
#   'pink',
#   'boa',
#   'stopping',
#   'bicycle',
#   'bridge',
#   'built',
#   'pedestrians'],
#  ['woman',
#   'wearing',
#   'pink',
#   'boa',
#   'riding',
#   'bicycle',
#   'bridge',
#   'built',
#   'pedestrians'],
#  ['woman',
#   'wearing',
#   'pink',
#   'scarf',
#   'riding',
#   'bike',
#   'bridge',
#   'built',
#   'pedestrians'],
#  ['woman',
#   'wearing',
#   'pink',
#   'boa',
#   'riding',
#   'bicycle',
#   'bridge',
#   'built',
#   'pedestrians'],
#  ['person', 'riding', 'bike', 'wearing', 'gear', 'black'],
#  ['biker', 'naked'],
#  ['black', 'helmet', 'worn', 'man', 'pushing', 'bicycle'],
#  ['biker', 'wearing', 'gear', 'black'],
#  ['one', 'man', 'wearing', 'black', 'helmet', 'pushing', 'bicycle'],
#  ['man', 'grey', 'tshirt', 'sitting', 'rock', 'front', 'waterfall'],
#  ['man', 'grey', 'tshirt', 'sitting', 'rock', 'front', 'waterfall'],
#  ['woman', 'standing', 'isnt', 'looking', 'waterfall'],
#  ['woman', 'standing', 'isnt', 'looking', 'waterfall'],
#  ['man', 'tshirt', 'dyed', 'grey', 'sitting', 'rock', 'front', 'waterfall'],
#  ['man', 'grey', 'tshirt', 'sitting', 'rock', 'front', 'waterfall'],
#  ['woman', 'sitting', 'looking', 'waterfall'],
#  ['dog', 'brown', 'black', 'one', 'running', 'grass'],
#  ['black', 'man', 'running', 'brown', 'grass', 'racing', 'dog'],
#  ['dark', 'black', 'dog', 'light', 'brown', 'dog', 'playing', 'yard', 'back'],
#  ['dark', 'black', 'dog', 'light', 'brown', 'dog', 'playing', 'yard', 'back'],
#  ['dark', 'black', 'dog', 'light', 'brown', 'dog', 'fighting', 'backyard'],
#  ['dog', 'running', 'grass'],
#  ['dark', 'black', 'dog', 'light', 'brown', 'dog', 'playing', 'backyard'],
#  ['dog', 'brown', 'white', 'coat', 'sitting', 'shallow', 'water'],
#  ['white', 'brown', 'dog', 'walking', 'water', 'difficulty'],
#  ['group', 'boys', 'quiet', 'front', 'large', 'door', 'made', 'wood'],
#  ['children', 'arent', 'playing', 'front', 'large', 'door'],
#  ['bunch',
#   'boys',
#   'playing',
#   'ball',
#   'front',
#   'large',
#   'door',
#   'made',
#   'wood'],
#  ['children', 'playing', 'front', 'large', 'door'],
#  ['black', 'red', 'white', 'pink', 'dress', 'worn', 'woman'],
#  ['woman', 'taking', 'cloak', 'large', 'revealing', 'extravagant', 'dress'],
#  ['teenage', 'girl', 'storing', 'away', 'beads', 'red'],
#  ['young',
#   'lady',
#   'light',
#   'brown',
#   'hair',
#   'wearing',
#   'red',
#   'necklace',
#   'sweatshirt',
#   'earrings',
#   'smiling'],
#  ['young',
#   'lady',
#   'light',
#   'brown',
#   'hair',
#   'wearing',
#   'red',
#   'necklace',
#   'sweatshirt',
#   'earrings',
#   'smiling'],
#  ['young',
#   'lady',
#   'light',
#   'brown',
#   'hair',
#   'wearing',
#   'red',
#   'necklace',
#   'sweatshirt',
#   'earrings',
#   'smiling'],
#  ['lady',
#   'young',
#   'age',
#   'light',
#   'brown',
#   'hair',
#   'wearing',
#   'red',
#   'necklace',
#   'sweatshirt',
#   'earrings',
#   'smiling'],
#  ['young',
#   'lady',
#   'light',
#   'brown',
#   'hair',
#   'wearing',
#   'red',
#   'necklace',
#   'sweatshirt',
#   'earrings',
#   'smiling'],
#  ['girl', 'likes', 'red', 'isnt', 'wearing', 'beads', 'teenagers'],
#  ['fearful', 'little', 'boy', 'climbing', 'wall'],
#  ['boy',
#   'climbing',
#   'wall',
#   'artificially',
#   'built',
#   'climbing',
#   'attached',
#   'rope'],
#  ['fearful', 'little', 'boy', 'climbing', 'wall'],
#  ['boy',
#   'climbing',
#   'wall',
#   'artificially',
#   'built',
#   'climbing',
#   'attached',
#   'rope'],
#  ['dad', 'launching', 'daughter', 'swimming', 'pool'],
#  ['father', 'swimming', 'pool', 'daughters', 'launch'],
#  ['man', 'tossing', 'kid', 'swimming', 'pool', 'near', 'ocean'],
#  ['man', 'tossing', 'kid', 'swimming', 'pool', 'near', 'ocean'],
#  ['one', 'man', 'tossing', 'kid', 'swimming', 'pool', 'near', 'ocean'],
#  ['kid', 'swimming', 'ocean', 'tossing', 'coin', 'pool', 'near', 'man'],
#  ['father', 'swimming', 'pool', 'daughters', 'launch'],
#  ['father', 'launching', 'daughter', 'swimming', 'pool'],
#  ['social', 'climber', 'tying', 'man', 'cliff', 'rope'],
#  ['person', 'standing', 'front', 'rock', 'rope', 'pink'],
#  ['rock', 'climbed', 'person', 'rope', 'pink'],
#  ['one', 'man', 'climbing', 'cliff', 'rope'],
#  ['person', 'climbing', 'rock', 'rope', 'pink'],
#  ['person', 'climbing', 'rock', 'rope', 'pink'],
#  ['person', 'climbing', 'rock', 'rope', 'pink'],
#  ['young', 'boy', 'isnt', 'climbing', 'wall', 'made', 'rock'],
#  ['young', 'child', 'climbing', 'rock', 'climbing', 'wall', 'indoors'],
#  ['young', 'child', 'climbing', 'rock', 'climbing', 'wall', 'indoors'],
#  ['child',
#   'indoors',
#   'watching',
#   'program',
#   'young',
#   'climbers',
#   'rock',
#   'wall'],
#  ['one', 'young', 'boy', 'climbing', 'wall', 'made', 'rock'],
#  ['young', 'climber', 'making', 'rock', 'wall', 'boys'],
#  ['cyclist', 'performing', 'trick', 'air'],
#  ['one', 'man', 'bicycle', 'trick', 'midair'],
#  ['one', 'man', 'bicycle', 'trick', 'midair'],
#  ['dog', 'black', 'white', 'one', 'staring', 'street'],
#  ['dog', 'black', 'white', 'one', 'staring', 'street'],
#  ['two',
#   'dogs',
#   'different',
#   'breeds',
#   'looking',
#   'angrily',
#   'across',
#   'street'],
#  ['two', 'dogs', 'different', 'breeds', 'looking', 'across', 'street'],
#  ['dog', 'black', 'another', 'one', 'white', 'staring', 'street'],
#  ['dog', 'next', 'tree', 'probably', 'pine', 'dropping', 'bucket'],
#  ['dog', 'next', 'tree', 'probably', 'pine', 'biting', 'bucket'],
#  ['dog', 'furry', 'black', 'backyard', 'carrying', 'basket', 'mouth'],
#  ['dog', 'furry', 'black', 'back', 'yard', 'carrying', 'basket', 'mouth'],
#  ['dog', 'next', 'tree', 'probably', 'pine', 'biting', 'bucket'],
#  ['dog', 'backyard', 'carrying', 'black', 'fur', 'basket', 'mouth'],
#  ['dog', 'furry', 'black', 'back', 'yard', 'carrying', 'basket', 'mouth'],
#  ['two',
#   'persons',
#   'large',
#   'size',
#   'sitting',
#   'park',
#   'bench',
#   'bottle',
#   'soda'],
#  ['two', 'large', 'persons', 'sitting', 'park', 'bench', 'bottle', 'soda'],
#  ['two', 'large', 'park', 'benches', 'person', 'sitting', 'bottle', 'soda'],
#  ['man', 'woman', 'sitting', 'comfortably', 'bench'],
#  ['man', 'racing', 'lead'],
#  ['men', 'competition', 'running', 'outside'],
#  ['man', 'bringing', 'rear', 'race'],
#  ['men', 'competition', 'running', 'outside'],
#  ['man', 'camera', 'studying', 'subject'],
#  ['man', 'camera', 'studying', 'subject'],
#  ['man', 'dyed', 'purple', 'hat', 'operating', 'camera', 'makes', 'videos'],
#  ['man', 'purple', 'hat', 'isnt', 'operating', 'camera', 'makes', 'videos'],
#  ['man', 'dyed', 'purple', 'hat', 'operating', 'camera', 'makes', 'videos'],
#  ['man', 'camera', 'studying', 'subject'],
#  ['man', 'purple', 'hat', 'operating', 'camera', 'makes', 'videos'],
#  ['man', 'purple', 'hat', 'operating', 'camera', 'makes', 'videos'],
#  ['study', 'subject', 'camera', 'man'],
#  ['man', 'purple', 'hat', 'operating', 'camera', 'makes', 'videos'],
#  ['bride', 'groom', 'leaving', 'marriage'],
#  ['bride', 'groom', 'arriving', 'wedding'],
#  ['married', 'couple', 'walking', 'aisle'],
#  ['priest', 'walking', 'aisle', 'marry', 'couple'],
#  ['bride', 'groom', 'leaving', 'marriage'],
#  ['bride', 'groom', 'arriving', 'wedding'],
#  ['married', 'couple', 'walking', 'aisle'],
#  ['married', 'couple', 'walking', 'aisle'],
#  ['presentation', 'watched', 'classroom', 'students'],
#  ['presentation', 'attended', 'classroom', 'students'],
#  ['presentation', 'watched', 'classroom', 'students'],
#  ['boy',
#   'hill',
#   'covered',
#   'snow',
#   'wearing',
#   'red',
#   'jacket',
#   'black',
#   'hat',
#   'sliding',
#   'knees'],
#  ['boy',
#   'hill',
#   'covered',
#   'snow',
#   'wearing',
#   'red',
#   'jacket',
#   'black',
#   'hat',
#   'sliding',
#   'knees'],
#  ['kid', 'happily', 'sliding', 'snow'],
#  ['snow', 'slide', 'full', 'kids'],
#  ['boy',
#   'hill',
#   'covered',
#   'snow',
#   'wearing',
#   'red',
#   'jacket',
#   'black',
#   'hat',
#   'sliding',
#   'knees'],
#  ['kid', 'sliding', 'snow'],
#  ['woman', 'dog', 'peacefully', 'sitting', 'tree', 'stump'],
#  ['woman', 'old', 'near', 'dog', 'white', 'coat'],
#  ['woman', 'old', 'far', 'white', 'dog'],
#  ['man', 'watering', 'grass', 'excitedly', 'playing', 'dog'],
#  ['dog', 'biting', 'droplets', 'water'],
#  ['dog', 'snapping', 'droplets', 'water'],
#  ['dog', 'excitedly', 'playing', 'water', 'grass'],
#  ['dog', 'snapping', 'droplets', 'water'],
#  ['man', 'watering', 'grass', 'excitedly', 'playing', 'dog'],
#  ['dog', 'snapping', 'droplets', 'water'],
#  ['two', 'people', 'snow', 'wearing', 'clothes', 'provide', 'camouflage'],
#  ['nobody', 'snow', 'wearing', 'clothes', 'provide', 'camouflage'],
#  ['people', 'snow', 'wearing', 'clothes', 'provide', 'camouflage'],
#  ['two', 'people', 'snow', 'wearing', 'clothes', 'provide', 'camouflage'],
#  ['two', 'people', 'snow', 'wearing', 'clothes', 'provide', 'camouflage'],
#  ['girl', 'wearing', 'tshirt', 'keeping', 'mouth', 'open'],
#  ['girl', 'asia', 'front', 'window', 'made', 'bricks', 'looks', 'surprised'],
#  ['girl', 'asia', 'front', 'brick', 'window', 'doesnt', 'look', 'surprised'],
#  ['person', 'biking', 'gear', 'standing', 'steadily', 'front', 'mountains'],
#  ['person', 'bike', 'gear', 'standing', 'steadily', 'front', 'mountains'],
#  ['group', 'people', 'equipped', 'gear', 'used', 'protection'],
#  ['group', 'people', 'equipped', 'unprotective', 'gear'],
#  ['little', 'kid', 'playing', 'football', 'falling', 'harmlessly', 'grass'],
#  ['little', 'kid', 'playing', 'football', 'falling', 'grass'],
#  ['football', 'feet', 'boy', 'lying', 'grass'],
#  ['football', 'feet', 'boy', 'lying', 'grass'],
#  ['man',
#   'equipment',
#   'used',
#   'climbing',
#   'hanging',
#   'white',
#   'vertical',
#   'rock'],
#  ['woman', 'ponytail', 'climbing', 'wall', 'rock'],
#  ['woman', 'ponytail', 'climbing', 'wall', 'rock'],
#  ['man',
#   'equipment',
#   'used',
#   'climbing',
#   'hanging',
#   'white',
#   'vertical',
#   'rock'],
#  ['woman', 'tailing', 'pony', 'near', 'rock', 'climbing', 'wall'],
#  ['woman', 'ponytail', 'climbing', 'wall', 'rock'],
#  ['man',
#   'equipment',
#   'used',
#   'climbing',
#   'hanging',
#   'white',
#   'vertical',
#   'rock'],
#  ['black', 'white', 'dog', 'joyfully', 'running', 'grass'],
#  ['one',
#   'white',
#   'dog',
#   'one',
#   'black',
#   'one',
#   'sitting',
#   'side',
#   'side',
#   'grass'],
#  ['one',
#   'white',
#   'dog',
#   'one',
#   'black',
#   'one',
#   'cheerfully',
#   'running',
#   'side',
#   'side',
#   'grass'],
#  ['one',
#   'white',
#   'dog',
#   'one',
#   'black',
#   'one',
#   'sitting',
#   'side',
#   'side',
#   'grass'],
#  ['black', 'person', 'white', 'joyfully', 'running', 'dog', 'grass'],
#  ['lot', 'people', 'ice', 'skating', 'park'],
#  ['many', 'people', 'skating', 'ice', 'park'],
#  ['ice', 'skating', 'rink', 'placed', 'outdoors', 'full', 'people'],
#  ['ice', 'skating', 'rink', 'placed', 'outdoors', 'empty'],
#  ['ice', 'skating', 'rink', 'placed', 'outdoors', 'full', 'people'],
#  ['ice', 'skating', 'rink', 'placed', 'outdoors', 'full', 'people'],
#  ['lot', 'people', 'ice', 'skating', 'park'],
#  ['ice', 'skating', 'rink', 'placed', 'outdoors', 'full', 'people'],
#  ['ice', 'skating', 'rink', 'placed', 'outdoors', 'full', 'people'],
#  ['girl', 'uniform', 'blue', 'lowering', 'arm'],
#  ['girl', 'raising', 'blue', 'uniform', 'arm'],
#  ['girl', 'blue', 'white', 'uniform', 'cheering'],
#  ['girl', 'blue', 'white', 'uniform', 'isnt', 'cheering'],
#  ['cheers', 'performed', 'girl', 'blue', 'white', 'uniform'],
#  ['girl', 'blue', 'white', 'uniform', 'cheering'],
#  ['girl', 'raising', 'blue', 'uniform', 'arm'],
#  ['girl', 'uniform', 'blue', 'raising', 'arm'],
#  ['people', 'beach', 'full', 'sand', 'ocean', 'enjoying', 'sunny', 'day'],
#  ['people',
#   'far',
#   'beach',
#   'full',
#   'sand',
#   'ocean',
#   'suffering',
#   'sunny',
#   'day'],
#  ['people',
#   'far',
#   'beach',
#   'full',
#   'sand',
#   'ocean',
#   'suffering',
#   'sunny',
#   'day'],
#  ['people', 'beach', 'full', 'sand', 'ocean', 'enjoying', 'sunny', 'day'],
#  ['man', 'wheelie', 'motorbike', 'field', 'mostly', 'barren'],
#  ['man', 'wheelie', 'motorcycle', 'ground', 'mostly', 'barren'],
#  ['man',
#   'blue',
#   'jumpsuit',
#   'courageously',
#   'performing',
#   'wheelie',
#   'motorcycle'],
#  ['man',
#   'blue',
#   'jumpsuit',
#   'courageously',
#   'performing',
#   'wheelie',
#   'motorcycle'],
#  ['man', 'blue', 'jumpsuit', 'failing', 'perform', 'wheelie', 'motorcycle'],
#  ['man', 'wheelie', 'motorcycle', 'ground', 'mostly', 'barren'],
#  ['two', 'people', 'arguing', 'near', 'crowd'],
#  ['two', 'people', 'passionately', 'kissing', 'near', 'crowd'],
#  ['two', 'people', 'kissing', 'near', 'crowd'],
#  ['two', 'people', 'kissing', 'near', 'crowd'],
#  ['young', 'girl', 'blowing', 'bubble', 'huge'],
#  ['young', 'girl', 'blowing', 'bubble', 'huge'],
#  ['bubble', 'blew', 'dyeing', 'girls', 'shirt', 'red'],
#  ['young', 'child', 'barefoot', 'walking', 'past', 'puddle', 'full', 'mud'],
#  ['young',
#   'child',
#   'wearing',
#   'green',
#   'boots',
#   'playing',
#   'puddle',
#   'full',
#   'mud'],
#  ['young',
#   'child',
#   'wearing',
#   'green',
#   'boots',
#   'playing',
#   'puddle',
#   'full',
#   'mud'],
#  ['little', 'boy', 'jumping', 'puddle', 'street'],
#  ['young', 'child', 'barefoot', 'walking', 'past', 'puddle', 'full', 'mud'],
#  ['green',
#   'boots',
#   'puddle',
#   'full',
#   'mud',
#   'targeted',
#   'playful',
#   'young',
#   'child',
#   'wearing',
#   'scarf'],
#  ['two', 'toddlers', 'sleeping', 'wagon', 'really', 'small'],
#  ['two', 'toddlers', 'eating', 'really', 'small', 'wagon', 'full', 'corndogs'],
#  ['two', 'young', 'kids', 'eating', 'corndogs'],
#  ['two', 'toddlers', 'eating', 'corndogs', 'wagon', 'really', 'small'],
#  ['corndogs', 'eaten', 'two', 'toddlers', 'wagon', 'really', 'small'],
#  ['two', 'toddlers', 'sleeping', 'wagon', 'really', 'small'],
#  ['two', 'toddlers', 'eating', 'corndogs', 'wagon', 'really', 'small'],
#  ['man',
#   'shirt',
#   'dyed',
#   'purple',
#   'looking',
#   'man',
#   'black',
#   'shirt',
#   'funny',
#   'face'],
#  ['man',
#   'shirt',
#   'dyed',
#   'purple',
#   'walking',
#   'away',
#   'man',
#   'black',
#   'shirt',
#   'serious'],
#  ['man',
#   'shirt',
#   'dyed',
#   'purple',
#   'looking',
#   'man',
#   'black',
#   'shirt',
#   'funny',
#   'face'],
#  ['man', 'pose', 'amusedly', 'watched', 'another', 'man'],
#  ['man',
#   'shirt',
#   'dyed',
#   'purple',
#   'looking',
#   'man',
#   'black',
#   'shirt',
#   'funny',
#   'face'],
#  ['man', 'pose', 'watched', 'another', 'man'],
#  ['horse', 'tossing', 'cowboy', 'wearing', 'pants', 'blue', 'red', 'color'],
#  ['horse', 'tossing', 'cowboy', 'wearing', 'pants', 'blue', 'red', 'color'],
#  ['man', 'laying', 'cover', 'wild', 'horse', 'falling', 'track'],
#  ['man', 'abruptly', 'falling', 'horse', 'track', 'laid', 'wild'],
#  ['man', 'falling', 'horse', 'track', 'laid', 'wild'],
#  ['man', 'falling', 'horse', 'track', 'laid', 'wild'],
#  ['man', 'boy', 'standing', 'bottom', 'stairs', 'outdoors'],
#  ['man', 'boy', 'standing', 'bottom', 'stairs', 'outdoors'],
#  ['adult', 'amphitheater', 'talking', 'boy'],
#  ['adult', 'amphitheater', 'talking', 'boy'],
#  ['man', 'boy', 'standing', 'bottom', 'stairs', 'outdoors'],
#  ['boy',
#   'red',
#   'shirt',
#   'front',
#   'long',
#   'blue',
#   'wall',
#   'suspiciously',
#   'raising',
#   'eyebrow',
#   'camera'],
#  ['boy',
#   'standing',
#   'front',
#   'blue',
#   'building',
#   'space',
#   'reserved',
#   'handicapped',
#   'people'],
#  ['boy',
#   'red',
#   'shirt',
#   'front',
#   'long',
#   'blue',
#   'wall',
#   'suspiciously',
#   'raising',
#   'eyebrow',
#   'camera'],
#  ['boy',
#   'red',
#   'shirt',
#   'front',
#   'long',
#   'blue',
#   'wall',
#   'suspiciously',
#   'raising',
#   'eyebrow',
#   'camera'],
#  ['jockeys', 'riding', 'horses', 'field', 'completely', 'green'],
#  ['jockeys', 'racing', 'horses', 'field', 'completely', 'green'],
#  ['green', 'field', 'horse', 'races', 'completely', 'full', 'jockeys'],
#  ['furious',
#   'racers',
#   'green',
#   'grass',
#   'yelling',
#   'horses',
#   'jumping',
#   'obstacle'],
#  ['horses', 'racing', 'furiously', 'green', 'grass', 'jumping', 'obstacle'],
#  ['horses', 'racing', 'furiously', 'green', 'grass', 'jumping', 'obstacle'],
#  ['woman',
#   'wearing',
#   'sunglasses',
#   'large',
#   'size',
#   'holding',
#   'newspapers',
#   'hands'],
#  ['woman',
#   'wearing',
#   'sunglasses',
#   'large',
#   'size',
#   'holding',
#   'newspapers',
#   'hands'],
#  ['old',
#   'woman',
#   'wearing',
#   'shirt',
#   'rose',
#   'pattern',
#   'upon',
#   'clumsily',
#   'carrying',
#   'two',
#   'newspapers'],
#  ['old',
#   'woman',
#   'wearing',
#   'rose',
#   'patterned',
#   'shirt',
#   'clumsily',
#   'carrying',
#   'two',
#   'newspapers'],
#  ['old',
#   'woman',
#   'wearing',
#   'rose',
#   'patterned',
#   'shirt',
#   'clumsily',
#   'carrying',
#   'two',
#   'newspapers'],
#  ['old',
#   'woman',
#   'wearing',
#   'rose',
#   'patterned',
#   'shirt',
#   'clumsily',
#   'carrying',
#   'two',
#   'newspapers'],
#  ['person', 'practicing', 'snowboarding', 'falls', 'air'],
#  ['snowboarder', 'leaping', 'white', 'snow'],
#  ['snowboarder', 'leaping', 'fearlessly', 'white', 'snow'],
#  ['practicing', 'jumper', 'tossing', 'persons', 'snowboard', 'air'],
#  ['snowboarder', 'leaping', 'white', 'snow'],
#  ['dog', 'near', 'ball', 'colored', 'red', 'air'],
#  ['dog', 'near', 'red', 'ball', 'air'],
#  ['dog', 'jumping', 'air', 'catch', 'red', 'ball'],
#  ['dog', 'small', 'playing', 'tirelessly', 'green', 'grass'],
#  ['dog', 'small', 'playing', 'green', 'grass'],
#  ['dog', 'small', 'playing', 'green', 'grass'],
#  ['dog', 'small', 'running', 'green', 'grass'],
#  ['dog', 'near', 'red', 'ball', 'air'],
#  ['dog', 'small', 'playing', 'green', 'grass'],
#  ['dog', 'far', 'red', 'ball', 'air'],
#  ['dog', 'near', 'red', 'ball', 'air'],
#  ['man', 'riding', 'motorbike', 'event', 'related', 'motocross'],
#  ['person', 'riding', 'motorbike', 'sandy', 'track'],
#  ['person', 'riding', 'motorbike', 'event', 'related', 'motocross'],
#  ['person', 'riding', 'motorbike', 'event', 'related', 'motocross'],
#  ['motorbike', 'rider', 'jumping', 'person', 'sandy', 'track'],
#  ['young', 'girl', 'pink', 'shirt', 'peacefully', 'lying', 'grass'],
#  ['girl', 'wearing', 'pink', 'shirt', 'white', 'writing', 'lying', 'grass'],
#  ['young', 'girl', 'pink', 'shirt', 'peacefully', 'lying', 'grass'],
#  ['dog', 'large', 'size', 'running', 'grass', 'tennis', 'ball', 'mouth'],
#  ['large', 'dog', 'running', 'grass', 'tennis', 'ball', 'mouth'],
#  ['large', 'dog', 'running', 'grass', 'tennis', 'ball', 'mouth'],
#  ['dog',
#   'large',
#   'gray',
#   'carrying',
#   'ball',
#   'mouth',
#   'running',
#   'across',
#   'grass'],
#  ['large', 'dog', 'running', 'grass', 'tennis', 'ball', 'mouth'],
#  ['large',
#   'gray',
#   'ball',
#   'hitting',
#   'running',
#   'dog',
#   'carrying',
#   'grass',
#   'mouth'],
#  ['dog',
#   'large',
#   'gray',
#   'carrying',
#   'ball',
#   'mouth',
#   'running',
#   'across',
#   'grass'],
#  ['dog',
#   'large',
#   'gray',
#   'carrying',
#   'ball',
#   'mouth',
#   'running',
#   'across',
#   'grass'],
#  ['large',
#   'tennis',
#   'ball',
#   'used',
#   'teach',
#   'dog',
#   'run',
#   'grass',
#   'catch',
#   'mouth'],
#  ['dog',
#   'large',
#   'gray',
#   'carrying',
#   'ball',
#   'mouth',
#   'running',
#   'across',
#   'grass'],
#  ['man', 'opening', 'small', 'package', 'contains', 'headphones'],
#  ['man', 'opening', 'package', 'contains', 'headphones'],
#  ['woman', 'riding', 'horse'],
#  ['man', 'wearing', 'headphones', 'opening', 'package'],
#  ['woman', 'riding', 'horse'],
#  ['man', 'opening', 'package', 'contains', 'headphones'],
#  ['man', 'singing', 'playing', 'guitar'],
#  ['man', 'singing', 'song', 'playing', 'guitar'],
#  ['man', 'opening', 'package', 'contains', 'headphones'],
#  ['man', 'singing', 'playing', 'guitar'],
#  ['dog', 'riding', 'skateboard', 'park'],
#  ['dog', 'riding', 'skateboard'],
#  ['dog', 'riding', 'skateboard'],
#  ['dog', 'riding', 'skateboard'],
#  ['fish', 'hunting', 'turtle', 'sea'],
#  ['turtle', 'following', 'red', 'fish'],
#  ['sea', 'turtle', 'hunting', 'fish'],
#  ['turtle', 'following', 'fish'],
#  ['woman', 'dipping', 'shrimp', 'batter'],
#  ['woman', 'dipping', 'shrimp', 'batter'],
#  ['man', 'playing', 'guitar'],
#  ['man', 'playing', 'piano'],
#  ['man', 'playing', 'guitar', 'windows'],
#  ['man', 'playing', 'guitar'],
#  ['woman', 'adding', 'ingredients', 'big', 'bowl'],
#  ['woman', 'cracking', 'eggs', 'container'],
#  ['woman', 'cracking', 'eggs', 'outside', 'bowl'],
#  ['woman', 'cracking', 'eggs', 'bowl'],
#  ['woman', 'slicing', 'carrot'],
#  ['woman', 'slicing', 'potato'],
#  ['woman', 'cooking', 'prawns'],
#  ['woman', 'boiling', 'shrimps'],
#  ['woman', 'boiling', 'shrimps'],
#  ['woman', 'boiling', 'shrimps'],
#  ['man', 'woman', 'hiking', 'wooded', 'area'],
#  ['man', 'woman', 'walking', 'together', 'wooded', 'areas'],
#  ['man', 'woman', 'walking', 'together', 'woods'],
#  ['man', 'making', 'speech', 'podium'],
#  ['man', 'speaking', 'podium'],
#  ['man', 'speaking', 'podium'],
#  ['man', 'tanking', 'stage', 'front', 'crowd'],
#  ['man', 'speaking', 'podium'],
#  ['man', 'making', 'speech', 'podium'],
#  ['man', 'speaking', 'stage'],
#  ['woman', 'talking', 'telephonic', 'device'],
#  ['woman', 'talking', 'telephone'],
#  ['woman', 'talking', 'telephonic', 'device'],
#  ['woman', 'talking', 'telephone'],
#  ['woman', 'talking', 'telephone'],
#  ['monkey', 'wading', 'marsh'],
#  ['small', 'monkey', 'walking', 'river'],
#  ['monkey', 'wading', 'river'],
#  ['small', 'monkey', 'walking', 'water'],
#  ['man', 'slicing', 'tomato'],
#  ['man', 'slicing', 'red', 'tomato'],
#  ['man', 'cutting', 'bun'],
#  ['woman', 'dancing', 'singing', 'women'],
#  ['woman', 'dancing', 'singing', 'rain'],
#  ['woman', 'removing', 'peel', 'potato'],
#  ['man', 'slicing', 'red', 'tomato'],
#  ['woman', 'peeling', 'potato'],
#  ['woman', 'removing', 'peel', 'potato'],
#  ['woman', 'slicing', 'tomato'],
#  ['woman', 'amalgamating', 'eggs'],
#  ['hungry', 'woman', 'eating'],
#  ['woman', 'eating'],
#  ['band', 'performing', 'stage'],
#  ['man', 'mixing'],
#  ['man', 'arranging', 'garden'],
#  ['man', 'mixing'],
#  ['man', 'mixing'],
#  ['man', 'shaking', 'drink'],
#  ['man', 'mixing'],
#  ['man', 'walking', 'yard'],
#  ['man', 'dancing'],
#  ['man', 'walking', 'outside'],
#  ['man', 'moving', 'gracefully'],
#  ['black', 'cat', 'swinging', 'fan'],
#  ['cat', 'swinging', 'fan'],
#  ['cat', 'playing', 'moving', 'ceiling', 'fan'],
#  ['black', 'cat', 'swinging', 'fan'],
#  ['cat', 'stuck', 'moving', 'ceiling', 'fan'],
#  ['man', 'playing', 'flute'],
#  ['man', 'playing', 'flute'],
#  ['man', 'making', 'music', 'flute'],
#  ['man', 'playing', 'flute'],
#  ['person', 'performing', 'card', 'trick'],
#  ['person', 'performing', 'card', 'trick'],
#  ['boy', 'spanking', 'man', 'plastic', 'sword'],
#  ['boy', 'spanking', 'man', 'plastic', 'sword'],
#  ['boy', 'whacking', 'man', 'sword'],
#  ['man', 'whacking', 'boy', 'sword'],
#  ['boy', 'whacking', 'man', 'sword'],
#  ['boy', 'whacking', 'man', 'sword'],
#  ['lady', 'measuring', 'ankle', 'another', 'woman'],
#  ['woman', 'measuring', 'man'],
#  ['man', 'making', 'phone', 'call'],
#  ['man', 'talking', 'cell', 'phone'],
#  ['man', 'talking', 'cell', 'phone'],
#  ['man', 'hanging', 'phone'],
#  ['man', 'making', 'call', 'cell', 'phone'],
#  ['dog', 'rolling', 'side', 'side'],
#  ['puppy', 'rolling'],
#  ['dog', 'rolling', 'side', 'side'],
#  ['puppy', 'repeatedly', 'rolling', 'side', 'side', 'back'],
#  ['machine', 'sharpening', 'pencil'],
#  ['machine', 'sharpening', 'knife'],
#  ['machine', 'shaving', 'pencil'],
#  ['machine', 'sharpening', 'knife'],
#  ['man', 'playing', 'keyboard'],
#  ['man', 'playing', 'keyboard'],
#  ['person', 'playing', 'keyboard'],
#  ['man', 'playing', 'keyboard', 'park'],
#  ['man', 'rinsing', 'large', 'steak'],
#  ['steak', 'rinsed', 'water', 'person'],
#  ['nobody', 'rinsing', 'steak', 'water'],
#  ['steak', 'rinsed', 'water', 'person'],
#  ['nobody', 'rinsing', 'steak', 'water'],
#  ['man', 'rinsing', 'large', 'steak'],
#  ['person', 'chopping', 'red', 'onion'],
#  ['person', 'chopping', 'onion'],
#  ['person', 'riding', 'old', 'motorcycle'],
#  ['person', 'riding', 'motorcycle'],
#  ['person', 'chopping', 'onion'],
#  ['man', 'screaming'],
#  ['butter', 'chopped', 'container', 'man'],
#  ['man', 'chopping', 'butter', 'small', 'container'],
#  ['prawn', 'cut', 'woman'],
#  ['man', 'chopping', 'butter', 'container'],
#  ['woman', 'cutting', 'shrimps'],
#  ['butter', 'chopped', 'container', 'man'],
#  ['men', 'sawing'],
#  ['men', 'sawing'],
#  ['men', 'sawing', 'logs'],
#  ['men', 'sawing'],
#  ['woman', 'washing', 'feet'],
#  ['woman', 'chopping', 'onion'],
#  ['woman', 'brushing', 'feet'],
#  ['man', 'playing', 'guitar'],
#  ['man', 'playing', 'keyboard'],
#  ['man', 'playing', 'guitar'],
#  ['man', 'playing', 'keyboard'],
#  ['man', 'playing', 'guitar'],
#  ['man', 'laughing'],
#  ['man', 'spitting'],
#  ['man', 'spreading', 'dough'],
#  ['man', 'spreading', 'dough'],
#  ['woman', 'slicing', 'meat', 'knife'],
#  ['baby', 'laughing'],
#  ['man', 'physical', 'activity'],
#  ['man', 'exercising'],
#  ['baby', 'crying'],
#  ['three', 'men', 'jumping', 'tall', 'wall'],
#  ['three', 'men', 'jumping', 'wall'],
#  ['three',
#   'young',
#   'men',
#   'running',
#   'jumping',
#   'kicking',
#   'near',
#   'vending',
#   'machine'],
#  ['three', 'men', 'jumping', 'wall'],
#  ['deer', 'standing', 'inside', 'fence'],
#  ['deer', 'jumping', 'low', 'fence'],
#  ['deer', 'jumping', 'cyclone', 'fence'],
#  ['deer', 'jumping', 'wall'],
#  ['deer', 'standing', 'inside', 'fence'],
#  ['deer', 'jumping', 'cyclone', 'fence'],
#  ['oil', 'stirred', 'man'],
#  ['man', 'stirring', 'sauce', 'chicken'],
#  ['man', 'stirring', 'oil'],
#  ['man', 'stirring', 'oil'],
#  ['man', 'playing', 'guitar'],
#  ['man', 'playing', 'guitar'],
#  ['man', 'playing', 'electric', 'guitar'],
#  ['man', 'playing', 'guitar'],
#  ['three', 'men', 'practicing', 'karate', 'field'],
#  ['three', 'men', 'practicing', 'karate', 'field'],
#  ['three', 'boys', 'karate', 'costumes', 'arent', 'fighting'],
#  ['women', 'holding', 'circle', 'dancing'],
#  ['two', 'men', 'playing', 'table', 'tennis'],
#  ['two', 'men', 'playing', 'table', 'football'],
#  ['women', 'holding', 'circle', 'dancing'],
#  ['two', 'men', 'playing', 'table', 'tennis'],
#  ['woman', 'cutting', 'broccoli'],
#  ['woman', 'planting', 'flowers'],
#  ['woman', 'cutting', 'plants'],
#  ['woman', 'cutting', 'flowers'],
#  ['woman', 'cutting', 'white', 'onion'],
#  ['woman', 'cutting', 'onion'],
#  ['woman', 'cutting', 'onion'],
#  ['white', 'horse', 'standing'],
#  ['horse', 'running'],
#  ['cat', 'playing', 'piano'],
#  ['man', 'playing', 'two', 'keyboards'],
#  ['man', 'playing', 'two', 'keyboards'],
#  ['mimes', 'performing', 'small', 'stage'],
#  ['men', 'acting', 'stage'],
#  ['two', 'men', 'leaving', 'stage'],
#  ['men', 'acting', 'stage'],
#  ['two', 'men', 'leaving', 'stage'],
#  ['men', 'performing', 'stage'],
#  ['man', 'dropping', 'tree'],
#  ['man', 'picking', 'tree'],
#  ['man', 'planting', 'tree'],
#  ['man', 'picking', 'tree'],
#  ['man', 'passionately', 'playing', 'guitar'],
#  ['man', 'playing', 'guitar'],
#  ['person', 'listening', 'trumpet', 'playing'],
#  ['man', 'playing', 'guitar'],
#  ['person', 'playing', 'trumpet'],
#  ['person', 'playing', 'trumpet'],
#  ['man', 'playing', 'guitar', 'owner'],
#  ['badger', 'shrewd', 'digging', 'earth'],
#  ['badger', 'shrewd', 'digging', 'earth'],
#  ['badger', 'shrewdly', 'digging', 'earth'],
#  ['badger', 'shrewdly', 'digging', 'earth'],
#  ['liquid', 'poured', 'pan', 'man'],
#  ['man', 'pouring', 'liquid', 'pot'],
#  ['chef', 'carefully', 'pouring', 'oil', 'pan'],
#  ['man', 'pouring', 'liquid', 'pot'],
#  ['man', 'pouring', 'liquid', 'pot'],
#  ['man', 'operating', 'stenograph'],
#  ['man', 'cautiously', 'operating', 'stenograph'],
#  ['man', 'typing', 'machine', 'used', 'stenography'],
#  ['man', 'operating', 'stenograph'],
#  ['snake', 'fed', 'mouse', 'man'],
#  ['poor', 'man', 'fed', 'snakes', 'mice'],
#  ['man', 'carefully', 'feeding', 'mouse', 'snake'],
#  ['man', 'carefully', 'feeding', 'mouse', 'snake'],
#  ['man', 'cautiously', 'feeding', 'mouse', 'snake'],
#  ['snake', 'fed', 'mouse', 'man'],
#  ['guy', 'cheerfully', 'playing', 'footbag'],
#  ['man', 'isnt', 'playing', 'piano'],
#  ['man', 'playing', 'piano'],
#  ['man', 'playing', 'piano'],
#  ['man', 'mixing', 'ingredients', 'bowl'],
#  ['person', 'bowling', 'ingredients', 'man', 'mixer'],
#  ['woman', 'breaking', 'two', 'eggs', 'bowl'],
#  ['woman', 'breaking', 'two', 'eggs', 'bowl'],
#  ['ingredients', 'mixed', 'bowl', 'person'],
#  ['woman', 'breaking', 'two', 'eggs', 'bowl'],
#  ['girl', 'recklessly', 'jumping', 'onto', 'car'],
#  ['girl', 'recklessly', 'jumping', 'onto', 'car'],
#  ['one', 'young', 'lady', 'jumping', 'car'],
#  ['girl', 'recklessly', 'jumping', 'onto', 'car'],
#  ['girl', 'recklessly', 'jumping', 'onto', 'car'],
#  ['girl', 'jumping', 'car'],
#  ['girl', 'recklessly', 'jumping', 'onto', 'vehicle'],
#  ['girl', 'isnt', 'jumping', 'onto', 'car', 'recklessly'],
#  ['car', 'riskily', 'jumping', 'girl'],
#  ['girl', 'recklessly', 'jumping', 'onto', 'car'],
#  ['one', 'woman', 'slowly', 'peeling', 'potato'],
#  ['woman', 'throwing', 'potato', 'peel'],
#  ['potato', 'peeled', 'woman'],
#  ['one', 'woman', 'peeling', 'potato'],
#  ['one', 'woman', 'slowly', 'peeling', 'potato'],
#  ['woman', 'peeling', 'potato'],
#  ['potato', 'peeled', 'woman'],
#  ['guitar', 'played', 'man'],
#  ['guitar', 'played', 'man'],
#  ['boat', 'sailing', 'peacefully', 'water'],
#  ['guitar', 'played', 'nobody'],
#  ['boat', 'sailing', 'quietly', 'water'],
#  ['boats', 'sail', 'reflected', 'peaceful', 'water'],
#  ['man', 'pouring', 'oil', 'tomatoes'],
#  ['oil', 'poured', 'tomatoes', 'man'],
#  ['man', 'pouring', 'oil', 'tomatoes'],
#  ['man', 'pouring', 'oil', 'tomatoes'],
#  ['milk', 'drunk', 'cat'],
#  ['kitten', 'drinking', 'fresh', 'milk'],
#  ['kitten', 'drinking', 'milk'],
#  ['kitten', 'drinking', 'fresh', 'milk'],
#  ['kitten', 'drinking', 'fresh', 'milk'],
#  ['frog', 'held', 'carelessly', 'man'],
#  ['man', 'carelessly', 'holding', 'frog'],
#  ['man', 'emptying', 'container', 'made', 'plastic'],
#  ['man', 'emptying', 'container', 'made', 'plastic'],
#  ['man', 'slicing', 'onion'],
#  ['man', 'eating', 'onion', 'slices'],
#  ['onion', 'cut', 'man'],
#  ['onion', 'cut', 'man'],
#  ['onion', 'sliced', 'man'],
#  ['onion', 'cut', 'man'],
#  ['man', 'recklessly', 'riding', 'horse'],
#  ['man', 'recklessly', 'riding', 'horse'],
#  ['man', 'recklessly', 'riding', 'horse'],
#  ['man', 'recklessly', 'riding', 'horse'],
#  ['somebody', 'playing', 'piano'],
#  ['piano', 'played', 'someone'],
#  ['one', 'man', 'turning', 'microwave'],
#  ['one', 'man', 'turning', 'microwave'],
#  ['one', 'man', 'turning', 'microwave'],
#  ['flute', 'played', 'girl'],
#  ['flute', 'played', 'girl'],
#  ['one', 'woman', 'practicing', 'flute'],
#  ['flute', 'played', 'girl'],
#  ['boy', 'happily', 'playing', 'piano'],
#  ['boy', 'isnt', 'playing', 'piano', 'happily'],
#  ['boy', 'happily', 'playing', 'piano'],
#  ['boy', 'happily', 'playing', 'piano'],
#  ['boy', 'happily', 'playing', 'piano'],
#  ['piano', 'played', 'man'],
#  ['boy', 'happily', 'playing', 'piano'],
#  ['cheetah', 'quickly', 'running', 'behind', 'prey'],
#  ['cheetah', 'quickly', 'running', 'behind', 'prey'],
#  ['cheetah', 'quickly', 'running', 'behind', 'prey'],
#  ['cheetah', 'chasing', 'prey', 'across', 'field'],
#  ['cheetah', 'chasing', 'prey', 'across', 'field'],
#  ['cheetah', 'shaken', 'prey', 'across', 'field'],
#  ['lion', 'pacing', 'tiredly', 'pen'],
#  ['lion', 'tiring', 'whole', 'pen', 'pacing'],
#  ['lion', 'slowly', 'walking'],
#  ['lion', 'pacing', 'tiredly', 'pen'],
#  ['man', 'playing', 'guitar', 'loudly'],
#  ['loud', 'man', 'allowed', 'play', 'guitar'],
#  ['man', 'playing', 'guitar', 'loudly'],
#  ['person', 'isnt', 'dicing', 'orange', 'pepper'],
#  ['person', 'dicing', 'pepper', 'orange'],
#  ['bells', 'ringing', 'near', 'cook', 'slicing', 'peppers'],
#  ['cook', 'slicing', 'bell', 'peppers'],
#  ['cook', 'slicing', 'bell', 'peppers'],
#  ['person', 'isnt', 'dicing', 'orange', 'pepper'],
#  ['person', 'dicing', 'pepper', 'orange'],
#  ['tofu', 'sliced', 'one', 'woman'],
#  ['tofu', 'sliced', 'woman'],
#  ['girl', 'cutting', 'butter', 'two', 'pieces'],
#  ['girl', 'little', 'combing', 'hair', 'pony', 'tail'],
#  ['girl', 'combing', 'hair', 'little', 'ponys', 'tail'],
#  ['one', 'man', 'sitting', 'steadily', 'chair'],
#  ['girl', 'little', 'combing', 'hair', 'pony', 'tail'],
#  ['girl', 'little', 'carefully', 'combing', 'hair', 'pony', 'tail'],
#  ['one', 'man', 'sitting', 'chair'],
#  ['man', 'carelessly', 'smearing', 'butter', 'slice', 'garlic', 'bread'],
#  ['man', 'spreading', 'butter', 'piece', 'bread', 'big'],
#  ['man', 'removing', 'butter', 'piece', 'bread', 'big'],
#  ['man', 'carelessly', 'smearing', 'butter', 'slice', 'garlic', 'bread'],
#  ['parrot', 'talking', 'microphone'],
#  ['parrot', 'speaking'],
#  ['kittens', 'hungry'],
#  ['man', 'eating', 'near', 'kittens'],
#  ['food', 'trays', 'isnt', 'eaten', 'kittens'],
#  ['kittens', 'eating', 'food', 'trays'],
#  ['food', 'trays', 'isnt', 'eaten', 'kittens'],
#  ['kittens', 'hungry'],
#  ['food', 'trays', 'eaten', 'kittens'],
#  ['person', 'singing', 'playing', 'guitar'],
#  ['person', 'singing', 'playing', 'guitar'],
#  ['man', 'passionately', 'playing', 'guitar'],
#  ['man', 'putting', 'away', 'guitar'],
#  ['man', 'passionately', 'playing', 'guitar'],
#  ['person', 'singing', 'playing', 'guitar'],
#  ['animals', 'playing', 'wildly', 'water'],
#  ['animals', 'playing', 'water'],
#  ['two', 'people', 'playing', 'ping', 'pong'],
#  ['two', 'people', 'playing', 'ping', 'pong'],
#  ['windows', 'polished', 'man'],
#  ['windows', 'cleaned', 'man'],
#  ['man', 'driving', 'car', 'carefully'],
#  ['man', 'driving', 'car'],
#  ['man', 'driving', 'car'],
#  ['windows', 'cleaned', 'man'],
#  ['woman', 'pouring', 'oil', 'skillet'],
#  ['woman', 'pouring', 'oil', 'skillet'],
#  ['baby', 'put', 'trash', 'woman'],
#  ['baby', 'put', 'trash', 'woman'],
#  ['baby', 'put', 'trash', 'woman'],
#  ['person', 'taking', 'away', 'meat', 'skillet'],
#  ['person', 'putting', 'meat', 'skillet'],
#  ['baby', 'put', 'trash', 'woman'],
#  ['one', 'small', 'child', 'greedily', 'drinking', 'water', 'cup'],
#  ['kitten', 'eagerly', 'drinking', 'milk', 'bowl'],
#  ['kitten', 'eagerly', 'drinking', 'milk', 'bowl'],
#  ['band', 'singing'],
#  ['singer', 'leaving', 'band'],
#  ['woman', 'putting', 'makeup', 'carefully'],
#  ['woman', 'putting', 'makeup', 'carefully'],
#  ['woman', 'happily', 'playing', 'guitar', 'acoustic', 'singing'],
#  ['singer', 'playing', 'guitar', 'acoustic', 'concert', 'woman'],
#  ['woman', 'happily', 'playing', 'guitar', 'acoustic', 'singing'],
#  ['singer', 'playing', 'guitar', 'acoustic', 'concert', 'woman'],
#  ['nobody', 'playing', 'guitar', 'singing'],
#  ['woman', 'playing', 'guitar', 'acoustic', 'singing'],
#  ['water', 'drunk', 'cat'],
#  ['truck', 'quickly', 'going', 'hill'],
#  ['truck', 'quickly', 'going', 'hill'],
#  ['water', 'drunk', 'cat'],
#  ['young', 'woman', 'playing', 'guitar'],
#  ['girl', 'playing', 'guitar'],
#  ['one', 'man', 'intensely', 'playing', 'guitar'],
#  ['man', 'intensely', 'playing', 'guitar'],
#  ['man', 'intensely', 'playing', 'guitar'],
#  ['girl', 'playing', 'guitar'],
#  ['intense', 'man', 'guitar', 'player'],
#  ['man', 'intensely', 'playing', 'guitar'],
#  ['girl', 'playing', 'guitar'],
#  ['man', 'riding', 'motorbike'],
#  ['man', 'parking', 'motorbike'],
#  ['man', 'riding', 'motorbike'],
#  ['horse', 'ridden', 'man'],
#  ['horse', 'ridden', 'man'],
#  ['motorbike', 'rider', 'running', 'man'],
#  ['man', 'riding', 'animal'],
#  ['man', 'ride', 'horse'],
#  ['magic', 'trick', 'performed', 'magician'],
#  ['man', 'isnt', 'magic', 'trick'],
#  ['man', 'magic', 'trick'],
#  ['man', 'dangerously', 'throwing', 'knives', 'tree'],
#  ['man', 'dangerously', 'throwing', 'knives', 'tree'],
#  ['man', 'dangerously', 'throwing', 'knives', 'tree'],
#  ['man', 'dangerously', 'throwing', 'knives', 'tree'],
#  ['kid', 'magic', 'tricking', 'old', 'man'],
#  ['guitar', 'played', 'lady'],
#  ['guitar', 'played', 'lady'],
#  ['man', 'practicing', 'guitar'],
#  ['practicing', 'person', 'doesnt', 'like', 'guitar'],
#  ['person', 'practicing', 'guitar'],
#  ['person', 'practicing', 'guitar'],
#  ['boy', 'enthusiastically', 'playing', 'mud'],
#  ['boy', 'playing', 'mud'],
#  ['cat', 'playing', 'device'],
#  ['boy', 'playing', 'mud'],
#  ['cat', 'playing', 'device'],
#  ['cat', 'playing', 'device'],
#  ['cat', 'playing', 'device'],
#  ['woman', 'eating', 'cut', 'pieces', 'raw', 'meat'],
#  ['lady', 'cutting', 'meat', 'precisely'],
#  ['lady', 'cutting', 'meat'],
#  ['meat', 'stitched', 'together', 'woman'],
#  ['boy', 'teens', 'talking', 'girl', 'internet', 'camera'],
#  ['boy', 'teens', 'talking', 'girl', 'webcam'],
#  ['one', 'man', 'talking', 'girl', 'internet', 'camera'],
#  ['man', 'ignoring', 'girl', 'via', 'internet', 'camera'],
#  ['man', 'ignoring', 'girl', 'via', 'internet', 'camera'],
#  ['one', 'man', 'talking', 'girl', 'internet', 'camera'],
#  ['one', 'man', 'talking', 'girl', 'internet', 'camera'],
#  ['eggs', 'strongly', 'whisked', 'bowl', 'person'],
#  ['person', 'strongly', 'whisking', 'eggs', 'bowl'],
#  ['woman', 'beating', 'two', 'eggs', 'bowl', 'using', 'whisk', 'made', 'wire'],
#  ['woman', 'beating', 'two', 'eggs', 'bowl', 'using', 'whisk', 'made', 'wire'],
#  ['woman',
#   'beating',
#   'man',
#   'keeping',
#   'two',
#   'eggs',
#   'bowl',
#   'using',
#   'wire',
#   'whisk'],
#  ['person', 'strongly', 'whisking', 'eggs', 'bowl'],
#  ['person', 'strongly', 'whisking', 'eggs', 'bowl'],
#  ['woman', 'beating', 'two', 'eggs', 'bowl', 'using', 'whisk', 'made', 'wire'],
#  ['woman', 'beating', 'two', 'eggs', 'bowl', 'using', 'whisk', 'made', 'wire'],
#  ['woman', 'beating', 'two', 'eggs', 'bowl', 'using', 'whisk', 'made', 'wire'],
#  ['interview', 'granted', 'man'],
#  ['interviewer', 'granting', 'break', 'man'],
#  ['white', 'car', 'driven', 'man'],
#  ['white', 'car', 'driven', 'man'],
#  ['man', 'granting', 'interview'],
#  ['white', 'car', 'driven', 'man'],
#  ['man', 'denying', 'interview'],
#  ['man', 'granting', 'interview'],
#  ['rope', 'climbed', 'man'],
#  ['man', 'roped', 'climber'],
#  ['man', 'mindlessly', 'slicing', 'carrot', 'machine'],
#  ['man', 'removing', 'carrot', 'machine'],
#  ['rope', 'climbed', 'man'],
#  ['rope', 'climbed', 'man'],
#  ['man', 'slicing', 'carrot', 'machine'],
#  ['rope', 'climbed', 'man'],
#  ['cat', 'licking', 'milk', 'saucer'],
#  ['milk', 'hungrily', 'drunk', 'cat'],
#  ['cat', 'hungrily', 'drinking', 'milk'],
#  ['cat', 'hungrily', 'drinking', 'milk'],
#  ['cat', 'licking', 'milk', 'saucer'],
#  ['drinking', 'milk', 'helps', 'cats', 'hunger'],
#  ['cat', 'licking', 'shallow', 'dish', 'full', 'milk'],
#  ['cat', 'isnt', 'licking', 'milk', 'saucer'],
#  ['cat', 'hungrily', 'drinking', 'milk'],
#  ['baby', 'playing', 'dog'],
#  ['woman', 'peeling', 'potato'],
#  ['man', 'slicing', 'potatoes'],
#  ['man', 'eating', 'potato', 'slices'],
#  ['woman', 'peeling', 'potato'],
#  ['man', 'slicing', 'potatoes'],
#  ['man', 'slicing', 'potatoes'],
#  ['man', 'slicing', 'potatoes'],
#  ['man', 'taking', 'pictures', 'lake'],
#  ['man', 'setting', 'camera', 'taking', 'sunset', 'pictures', 'beach'],
#  ['woman', 'unstitching', 'machine'],
#  ['woman', 'using', 'machine', 'made', 'sewing'],
#  ['woman', 'using', 'sewing', 'machine'],
#  ['woman', 'sewing', 'machine'],
#  ['woman', 'using', 'sewing', 'machine'],
#  ['egg', 'cracked', 'bowl', 'woman'],
#  ['woman', 'cracking', 'egg', 'bowl'],
#  ['woman', 'cracking', 'two', 'eggs', 'glass', 'bowl'],
#  ['woman', 'cracking', 'two', 'eggs', 'bowl', 'made', 'glass'],
#  ['woman', 'cracking', 'two', 'eggs', 'glass', 'bowl'],
#  ['woman', 'cracking', 'two', 'eggs', 'glass', 'bowl'],
#  ['woman', 'cracking', 'two', 'eggs', 'glass', 'bowl'],
#  ['men', 'watching', 'cricket'],
#  ['people', 'playing', 'cricket'],
#  ['men', 'cheerfully', 'playing', 'cricket'],
#  ['man', 'putting', 'garlic', 'bread', 'slices'],
#  ['man',
#   'sprinkling',
#   'seasoning',
#   'several',
#   'sliced',
#   'buttered',
#   'loaves',
#   'bread'],
#  ['man', 'putting', 'garlic', 'bread', 'slices'],
#  ['man', 'putting', 'garlic', 'slices', 'bread'],
#  ['man',
#   'sprinkling',
#   'seasoning',
#   'several',
#   'sliced',
#   'buttered',
#   'loaves',
#   'bread'],
#  ['two',
#   'kids',
#   'playing',
#   'swimming',
#   'pool',
#   'green',
#   'colored',
#   'crocodile',
#   'float'],
#  ['two',
#   'kids',
#   'playing',
#   'swimming',
#   'pool',
#   'green',
#   'colored',
#   'crocodile',
#   'float'],
#  ['inflatable', 'crocodile', 'pushed', 'two', 'kids', 'pool'],
#  ['two', 'kids', 'pushing', 'inflatable', 'crocodile', 'pool'],
#  ['two',
#   'kids',
#   'playing',
#   'swimming',
#   'pool',
#   'green',
#   'colored',
#   'crocodile',
#   'float'],
#  ['two',
#   'kids',
#   'playing',
#   'swimming',
#   'pool',
#   'green',
#   'colored',
#   'crocodile',
#   'float'],
#  ['two', 'kids', 'pushing', 'inflatable', 'crocodile', 'pool'],
#  ['two',
#   'crocodiles',
#   'floating',
#   'green',
#   'colored',
#   'swimming',
#   'pool',
#   'near',
#   'playing',
#   'kids'],
#  ['someone', 'falling', 'horse'],
#  ['someone', 'falling', 'horse'],
#  ['man', 'abruptly', 'knocked', 'horse'],
#  ['man', 'knocked', 'horse'],
#  ['woman', 'tapping', 'fingers', 'nervously'],
#  ['woman', 'tapping', 'fingers', 'desk'],
#  ['woman', 'tapping', 'fingers', 'table'],
#  ['woman', 'tapping', 'fingers'],
#  ['woman', 'tapping', 'fingers', 'table'],
#  ['dog', 'pushing', 'toddler', 'rain', 'puddle'],
#  ['dog', 'pushing', 'toddler', 'rain', 'puddle'],
#  ...]

# %%
# Importing pre-trained model, updating vocab 
# and training the model (takes long to run)
def pre_trained_w2v(corpus):
    '''Function to load the GoogleNews pre-trained word2vec and
    train it further on another corpus.
    
    Args:
        corpus: A list of lists where the sublists are sentences
                and the sublist items are words.
    Returns: 
        A word2vec model with a large vocabulary.
    '''
    w2v_model_2 = Word2Vec(size=300, min_count=1)
    w2v_model_2.build_vocab(corpus)
    total_examples = w2v_model_2.corpus_count
    w2v_google_model = gensim.models.KeyedVectors.load_word2vec_format('data/GoogleNews-vectors-negative300.bin', binary=True)
    w2v_model_2.build_vocab([list(w2v_google_model.vocab.keys())], update=True)
    w2v_model_2.intersect_word2vec_format('data/GoogleNews-vectors-negative300.bin', binary=True, lockf=1.0)
    # intersect_word2vec_format() will let you bring vectors from an external file into a model that's already had its own vocabulary initialized
    # see https://tedboy.github.io/nlps/generated/generated/gensim.models.Word2Vec.intersect_word2vec_format.html
    w2v_model_2.train(corpus, total_examples=total_examples, epochs=w2v_model_2.iter)
    return w2v_model_2
w2v_model_2 = pre_trained_w2v(corpus)
# Out:
# /Users/patrickrs/.conda/envs/pre-work/lib/python3.7/site-packages/ipykernel_launcher.py:21: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).

# %%
embedding_matrix = np.zeros((len(w2v_model_2.wv.vocab) + 1, 300))
for i, vec in enumerate(w2v_model_2.wv.vectors):
  embedding_matrix[i] = vec
feature_size = 500
tokenizer = Tokenizer(num_words = feature_size)
# fit the tokenizer on our text
tokenizer.fit_on_texts(pd.concat([data['sentence_A'], data['sentence_B']]))
# get all words that the tokenizer knows
word_index = tokenizer.word_index
# put the tokens in a matrix
X1 = tokenizer.texts_to_sequences(data['sentence_A'])
X1 = pad_sequences(X1)
X2 = tokenizer.texts_to_sequences(data['sentence_B'])
X2 = pad_sequences(X2)

# X2 was padded with one column less:
x0 = np.zeros((X2.shape[0], X1.shape[1]))
x0[:,X1.shape[1] - X2.shape[1]:] = X2
X2 = x0

X =  np.concatenate((X1, X2), axis = 1)
# prepare the labels
y = data['SimilarityScore']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.conda/envs/pre-work/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SimilarityScore'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-e0b2c128e7d0> in <module>
#      21 X =  np.concatenate((X1, X2), axis = 1)
#      22 # prepare the labels
# ---> 23 y = data['SimilarityScore']
#
# ~/.conda/envs/pre-work/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/.conda/envs/pre-work/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SimilarityScore'

# %%
# split in train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False, random_state = 42)
X1_train = X_train[:, :X1.shape[1]]
X2_train = X_train[:, X1.shape[1]:X_train.shape[1]]
X1_test = X_test[:, :X1.shape[1]]
X2_test = X_test[:, X1.shape[1]:X_train.shape[1]]

# %% [markdown]
# # Siamese Model

# %%
input_1 = Input(shape=(X1.shape[1],))
input_2 = Input(shape=(X2.shape[1],))


common_embed = Embedding(name = "Sentence_Embedd",
                        input_dim = len(w2v_model_2.wv.vocab) + 1 ,
                        output_dim = 300,
                        input_length  = X1.shape[1],
                        weights = [embedding_matrix],
                        trainable=False)
lstm_1 = common_embed(input_1)
lstm_2 = common_embed(input_2)


common_lstm = LSTM(64,return_sequences=True, activation="relu")
vector_1 = common_lstm(lstm_1)
vector_1 = Flatten()(vector_1)

vector_2 = common_lstm(lstm_2)
vector_2 = Flatten()(vector_2)

x3 = Subtract()([vector_1, vector_2])
x3 = Multiply()([x3, x3])

x1_ = Multiply()([vector_1, vector_1])
x2_ = Multiply()([vector_2, vector_2])
x4 = Subtract()([x1_, x2_])

# https://stackoverflow.com/a/51003359/10650182
# Calculates cosine similarity
x5 = keras.layers.Dot(axes = 1, normalize=True)([vector_1, vector_2])
    
conc = Concatenate(axis = -1)([x5, x4, x3])

x = Dense(100, activation="relu", name='conc_layer')(conc)
x = Dropout(0.2)(x)
out = Dense(1, activation="relu", name = 'out')(x)

model = Model([input_1, input_2], out)

model.compile(loss="mse",  metrics=[tf.keras.metrics.RootMeanSquaredError()], optimizer=Adam(0.00001))

# %% [markdown]
# In this network. input_1 and input_2 are pre-processed, Keras-tokenized text sequences which are to be compared for similar intent. These two text sequences are then fed through a common network of a basic embedding layer and an LSTM units. Once the feature vectors are obtained from this common network, a series of similarity measures are computed and are concatenated to be finally input into a Dense layer followed by sigmoid output unit which will finally help in classifying whether the given texts are similar or not.

# %%
model.summary()

# %%
plot_model(model, to_file='model.png', show_shapes=False)

# %%
'''Learning rate schedule
initial_learning_rate = 0.1
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=100000,
    decay_rate=0.96,
    staircase=True)'''

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        restore_best_weights=True,
        # Stop training when `val_loss` is no longer improving
        monitor='val_loss',
        # "no longer improving" being defined as "no better than 1e-2 less"
        min_delta=1e-2,
        # "no longer improving" being further defined as "for at least 10 epochs"
        patience=10,
        verbose=1)
            ]

# %%
batch = 1024
epochs = 1000
history = model.fit([X1_train, X2_train], y_train, 
                     batch, 
                     epochs = epochs, 
                     callbacks=callbacks,
                     validation_data = ([X1_test, X2_test], y_test)
                    )

# %%
print(history.history.keys())

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
data['sentence_A'][0]

# %%
# GRU better than LSTM? https://www.aclweb.org/anthology/R19-1116.pdf
